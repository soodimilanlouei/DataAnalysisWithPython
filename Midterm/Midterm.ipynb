# %% [markdown]
# # Midterm Exam
#
# First, we import required modules.
# Then we define the functions which are necessary to search and save the data.
#
# ## Functions:
# - *time_epoch*: StackExchange uses time entries in epoch format. This function converets the date entry to epoch format. You can see an example of the output of this function.
# - *search_save_question_tag*: This function search through questions in a specified time interval which contain some tags. It will check if there is anymore data on next pages. In that case, it will search through next page until there is no more data. Then the data will be saved in a json format. *time_epoch* is used inside this function.
# - *read_data*: This function takes the path of the file, and reads it.
# - *pretty_print* prints the data in a more readable form.

# %%
import requests
import json
import time
import operator
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def time_epoch(date_time = '2016 01 01',pattern = '%Y %m %d'):
    t_ephoc = str(int(time.mktime(time.strptime(date_time, pattern))))
    return t_ephoc

time_epoch('2016 01 01')
# Out:
# '1451624400'

# %%
def search_save_question_tag(tag, from_date, to_date):
    
    query = 'questions'
    key = 'Q8FdL9ZUYfXOw74bF8Q9Wg(('                           #This is the key which enables us to have a higher limit to search
    page = 1
    pattern = '%Y %m %d'
    formdate = time_epoch(from_date, pattern) 
    todate = time_epoch(to_date, pattern)
    
    # We need to make the correct url to send a request to StackExchange.
    
    url = 'https://api.stackexchange.com/2.2/'+query+'?key='+key+'&page='+str(page)+'&pagesize=100'+'&fromdate='+fromdate+ \
    '&todate='+todate+'&order=desc&min='+'&sort=activity&tagged='+tag+'&site=stackoverflow'
    
    results = requests.get(url).json()
    new_results = results['items']
    
    #Here, we make sure we also get all the data in next pages.
    
    while results['has_more']==True:
        
        page+=1
        print page
        url = 'https://api.stackexchange.com/2.0/'+query+'?key='+key+'&page='+str(page)+'&pagesize=100'+'&fromdate='+fromdate+ \
        '&todate='+todate+'&order=desc&min='+'&sort=activity&tagged='+tag+'&site=stackoverflow'
        results = requests.get(url).json()
        new_results += results['items']

    #At the end, we save the data in a json format to do analysis on later.
    
    path = query+tag
    with open(path+'.json', 'w') as file_out :
            json.dump(new_results, file_out,indent=2)

# %%
def read_data(path):
    with open(path ,'r') as json_data:
        data = json.load(json_data)
        
    return data

# %%
def pretty_print(jsondata) :
    print json.dumps(jsondata, indent=2)

# %% [markdown]
# # Analysis 1:
# ## Steps:
#    1. Get the questions with tag python and pandas. Inputs: tag='python;pandas', from_date='2016 01 01',to_date='2016 10 28'.
#    2. Read the data using *read_data*.
#    3. Parse the body for responses to collect a list of questions and user_id for the questions. To do so, we define two function: *get_question_list* and *get_user_id_list*.
#    4. Use the user_id obtained to send a request again to get user profile. Obtain the badges count to determine weightage. Since we have a set of user IDs, we can use */users/{ids}* method to get the profiles. *search_save_user_profile* will take care of this. There are three types of badges: Gold, Silver, and Bronze. We assume the weight of 10, 5, and 2 for each badge, respectively. The output of this step will be a dictionary in which user IDs are keys and the weightage of each user is the value. Since we can get the profiles for at most 100 users, we divide the user IDs in batches with size 100. *user_id_batch_100* will do this. Then we use *id_question* and *top_questions* to find the questions which users with high weightage asked.

# %%
tag = 'python;pandas'
from_date = '2016 01 01'
to_date = '2016 10 28'
search_save(query, tag, from_date, to_date)

# %%
def get_question_list(data):
    
    question_list = []
    
    #In order to get the questions out of the data, we store the value of key 'title'.
    for i in range(len(data)):
        question_list.append(data[i]['title'])
        
    return question_list

# %%
def get_user_id_list(data):
    
    user_id_list = []
    
    for i in range(len(data)):

        if 'user_id' in data[i]['owner']:
            user_id_list.append(data[i]['owner']['user_id'])
        else:
            continue

    #We return the user IDs information in both formats of set and list; set to have the unique IDs, 
    #and list, in case of finding the frequency of each user who asked questions with the specified tags.
    
    user_id_set = list(set(user_id_list))
    
    return user_id_list, user_id_set

# %%
#Read the data.

data_question_tag = read_data('questionspython;pandas.json')

# %%
# One example of how the data looks like.

pretty_print(data_question_tag[0])
# Out:
# {
#   "is_answered": true,
#   "tags": [
#     "python",
#     "pandas",
#     "numpy"
#   ],
#   "bounty_closes_date": 1478287199,
#   "title": "daily data, resample every 3 days, calculate over trailing 5 days efficiently",
#   "last_activity_date": 1477688683,
#   "answer_count": 2,
#   "creation_date": 1477272066,
#   "score": 3,
#   "link": "http://stackoverflow.com/questions/40209520/daily-data-resample-every-3-days-calculate-over-trailing-5-days-efficiently",
#   "bounty_amount": 500,
#   "owner": {
#     "user_id": 2336654,
#     "profile_image": "https://i.stack.imgur.com/cZOEs.jpg?s=128&g=1",
#     "user_type": "registered",
#     "reputation": 29968,
#     "link": "http://stackoverflow.com/users/2336654/pirsquared",
#     "accept_rate": 96,
#     "display_name": "piRSquared"
#   },
#   "view_count": 67,
#   "last_edit_date": 1477686080,
#   "question_id": 40209520
# }

# %%
question_list = get_question_list(data_question_tag)
user_id_list, user_id_set = get_user_id_list(data_question_tag)

print 'Number of questions = '+ str(len(question_list))
print 'Number of user IDs = ' + str(len(user_id_set))
# Out:
# Number of questions = 11174
# Number of user IDs = 5118

# %%
#Now, we know that we have 5118 unique IDs, we put them in batches with size 100 and the remiander in another list.
#Then, we join values in each batch together with ; to send the correct format of request.

def user_id_batch_100(user_data_set):
    
    user_id_100 = []
    list1 = user_id_set[0:100]
    list2 = user_id_set[100:200]
    list3 = user_id_set[200:300]
    list4 = user_id_set[300:400]
    list5 = user_id_set[400:500]
    list6 = user_id_set[500:-1]
    
    
    list11 = []
    for i in range(len(list1)):
        list11.append(str(list1[i]))
        
        
    list22 = []
    for i in range(len(list2)):
        list22.append(str(list2[i]))
        
    list33 = []
    for i in range(len(list3)):
        list33.append(str(list3[i]))
    list44 = []
    for i in range(len(list4)):
        list44.append(str(list4[i]))
    list55 = []
    for i in range(len(list5)):
        list55.append(str(list5[i]))
        
        
    u_format1 = ";".join(list11)
    u_format2 = ";".join(list22)
    u_format3 = ";".join(list33)
    u_format4 = ";".join(list44)
    u_format5 = ";".join(list55)

    user_id_100.append(u_format1)
    user_id_100.append(u_format2)
    user_id_100.append(u_format2)
    user_id_100.append(u_format2)
    user_id_100.append(u_format2)
    return user_id_100

        
    return user_id_100

# %%
user_batch = user_id_batch_100(user_id_set)

# %%
def search_save_user_profile(user_id_list):
    
    query = 'users'
    
    new_results = []
    
    for i in range(len(user_id_list)):
    
        key = 'Q8FdL9ZUYfXOw74bF8Q9Wg(('
        page = 1

        url = 'https://api.stackexchange.com/2.2/'+query+'/'+user_id_list[i]+'?key='+key+'&page='+str(page)+'&pagesize=100'+\
        '&order=desc&sort=reputation&site=stackoverflow'
        results = requests.get(url).json()
        new_results += results['items']


        while results['has_more']==True:

            page+=1
            print page
            url = 'https://api.stackexchange.com/2.2/'+query+'/'+user_id_list[i]+'?key='+key+'&page='+str(page)+\
            '&pagesize=100'+'&order=desc&sort=reputation&site=stackoverflow'
            results = requests.get(url).json()
            new_results += results['items']

    path = query+'Badge_count'
    with open(path+'.json', 'w') as file_out :
            json.dump(new_results, file_out,indent=2)

# %%
#Find and store the data.

search_save_user_profile(user_batch)

# %%
#Read the data.

data_user_badge_count = read_data('usersBadge_count.json')

# %%
# One example of how the data looks like.

pretty_print(data_user_badge_count[0])
# Out:
# {
#   "is_employee": false,
#   "last_access_date": 1476725496,
#   "user_id": 237696,
#   "account_id": 85196,
#   "badge_counts": {
#     "bronze": 71,
#     "silver": 38,
#     "gold": 4
#   },
#   "last_modified_date": 1477424115,
#   "profile_image": "https://i.stack.imgur.com/cUqoH.jpg?s=128&g=1",
#   "user_type": "registered",
#   "reputation_change_day": 0,
#   "creation_date": 1261583297,
#   "reputation_change_quarter": 89,
#   "reputation_change_year": 901,
#   "reputation": 7849,
#   "link": "http://stackoverflow.com/users/237696/mr-sk",
#   "location": "Bandar Seri Begawan, Brunei",
#   "accept_rate": 80,
#   "display_name": "mr-sk",
#   "reputation_change_month": 89,
#   "website_url": "http://www.nycdayz.com",
#   "reputation_change_week": 0
# }

# %%
#Define the weight of each badge.

weightage = {'gold': 10, 'silver':5, 'bronze':2}

# %%
def id_weightage(data, weightage):
    
    ids_weightage = {}
    
    for i in range(len(data)):
        ids_weightage[data[i]['user_id']] = data[i]['badge_counts']['gold']*weightage['gold']\
        +data[i]['badge_counts']['silver']*weightage['silver']+data[i]['badge_counts']['bronze']*weightage['bronze']
    
    #Sort the dictionary based on the reputation of each user.
    
    ids_weightage = sorted(ids_weightage.items(), key=operator.itemgetter(1), reverse=True)
    
    return ids_weightage

# %%
user_id_weightage = id_weightage(data_user_badge_count, weightage)

# %%
#This is how the result looks like.

user_id_weightage
# Out:
# [(1179880, 1118),
#  (344286, 718),
#  (712997, 473),
#  (854739, 440),
#  (557067, 395),
#  (237696, 372),
#  (852063, 250),
#  (845169, 236),
#  (860271, 164),
#  (680232, 163),
#  (1245262, 151),
#  (327702, 136),
#  (53468, 125),
#  (4168397, 115),
#  (1687633, 113),
#  (819330, 106),
#  (2227093, 101),
#  (2023745, 96),
#  (1155323, 89),
#  (1745038, 75),
#  (2457744, 71),
#  (2962786, 59),
#  (1119602, 58),
#  (945738, 54),
#  (3760132, 53),
#  (3842102, 53),
#  (3596337, 51),
#  (4698759, 50),
#  (3948664, 49),
#  (532570, 48),
#  (4169892, 45),
#  (2605262, 44),
#  (3407933, 41),
#  (2400377, 41),
#  (549094, 41),
#  (4931657, 38),
#  (3457053, 34),
#  (5759063, 34),
#  (2301970, 33),
#  (4005915, 33),
#  (1908806, 33),
#  (2965601, 33),
#  (909515, 32),
#  (5366046, 32),
#  (1946989, 30),
#  (2965673, 28),
#  (565514, 27),
#  (5491423, 27),
#  (2539738, 25),
#  (4661264, 24),
#  (4333609, 24),
#  (4388195, 24),
#  (5906433, 23),
#  (3768495, 23),
#  (4972716, 23),
#  (2277435, 22),
#  (5374161, 22),
#  (2564199, 21),
#  (4789642, 21),
#  (2621477, 20),
#  (5537840, 20),
#  (5505161, 20),
#  (4866196, 20),
#  (4317363, 20),
#  (5468983, 20),
#  (3136924, 20),
#  (3817518, 18),
#  (6201445, 18),
#  (5890240, 18),
#  (4750039, 18),
#  (2608081, 18),
#  (3121439, 18),
#  (3875107, 18),
#  (4661552, 18),
#  (2696565, 18),
#  (3358138, 18),
#  (1736893, 17),
#  (4444452, 17),
#  (5488652, 16),
#  (4111026, 16),
#  (2408643, 16),
#  (6537508, 16),
#  (1777919, 16),
#  (5063127, 16),
#  (4098013, 16),
#  (1785871, 15),
#  (3490069, 15),
#  (6692870, 14),
#  (1687586, 14),
#  (3072050, 14),
#  (6316050, 14),
#  (5521530, 14),
#  (3285014, 14),
#  (6545542, 14),
#  (2728074, 14),
#  (3956899, 14),
#  (2711738, 14),
#  (6470353, 14),
#  (6275292, 14),
#  (3637548, 14),
#  (5559673, 14),
#  (5213098, 14),
#  (5744566, 14),
#  (5283845, 12),
#  (4334596, 12),
#  (6455328, 12),
#  (6267003, 12),
#  (2605182, 12),
#  (6561949, 12),
#  (5865631, 12),
#  (4751525, 12),
#  (3178680, 12),
#  (6646464, 12),
#  (6136013, 12),
#  (5112032, 12),
#  (4350205, 12),
#  (3399944, 12),
#  (4383027, 12),
#  (5519631, 12),
#  (5431568, 12),
#  (5660947, 12),
#  (6635802, 12),
#  (4055335, 12),
#  (6185262, 12),
#  (5544925, 12),
#  (5563746, 12),
#  (6645104, 12),
#  (5115928, 10),
#  (3473471, 10),
#  (6529115, 10),
#  (1253493, 10),
#  (3997814, 10),
#  (5660808, 10),
#  (6168738, 10),
#  (6585004, 10),
#  (5759224, 10),
#  (5331808, 10),
#  (6462497, 8),
#  (3981355, 8),
#  (6373432, 8),
#  (6889536, 8),
#  (6242372, 8),
#  (5906506, 8),
#  (6111318, 8),
#  (5865585, 8),
#  (5595316, 8),
#  (5652674, 8),
#  (3334415, 8),
#  (5112031, 8),
#  (6382972, 8),
#  (3932482, 8),
#  (5812577, 8),
#  (4810108, 8),
#  (6070332, 6),
#  (6037573, 6),
#  (3686493, 6),
#  (5988450, 6),
#  (6291581, 6),
#  (6529170, 6),
#  (5619902, 6),
#  (6118101, 6),
#  (5742819, 6),
#  (1433643, 6),
#  (6881578, 6),
#  (3144099, 6),
#  (6801842, 6),
#  (3357137, 6),
#  (6291465, 4),
#  (6639629, 4),
#  (3022867, 4),
#  (3714634, 4),
#  (6185056, 4),
#  (6840427, 4),
#  (6676599, 4),
#  (6733959, 4),
#  (5947544, 4),
#  (6488274, 4),
#  (5390557, 4),
#  (2195729, 4),
#  (5390612, 4),
#  (7020856, 4),
#  (5232517, 4),
#  (6217748, 2),
#  (6414357, 2),
#  (5443623, 2),
#  (1998919, 2),
#  (6930507, 2),
#  (6758413, 2),
#  (6357081, 2),
#  (6176978, 2),
#  (6199534, 2),
#  (6684916, 2),
#  (3784956, 2),
#  (3318023, 2),
#  (6602969, 2),
#  (5552408, 2),
#  (3715124, 0),
#  (7069877, 0),
#  (6324437, 0),
#  (6537521, 0)]

# %%
def id_question(data):
    
    id_q = {}
    
    for i in range(len(data)):
        
        if 'user_id' in data[i]['owner']:
            id_q.setdefault(data[i]['owner']['user_id'],[])
            id_q[data[i]['owner']['user_id']].append(data[i]['title'])
        else:
            continue
    
    return id_q

# %%
user_id_question = id_question(data_question_tag)

# %%
def top_questions(id_weightage, id_question):
    
    #Since the id_weightage sorted based on the weightage, the first 5 entries of each question gives the most weighted users.
    
    for c in range(5):
        print 'User '+str(id_weightage[c][0])+ ' with weightage = '+str(id_weightage[c][1])+ ' >>> Question:\n '
        print id_question[id_weightage[c][0]]
        print '\n'

# %%
top_5_questions = top_questions(user_id_weightage,user_id_question)
# Out:
# User 1179880 with weightage = 1118 >>> Question:
#
# [u'Faster method of looping through pixels', u'pandas.set_option to give detail of Dataframe rather than returning frame', u'Applying different aggregate functions when using pivot_table', u'Complex pivot and resample', u'Marker colour still not showing up', u'Summary data for pandas dataframe', u'Is this approach &quot;vectorized&quot; - used against medium dataset it is relatively slow', u'More elegant conversion of Postgres data within pandas Dataframe', u'Why are these tuple values seemingly losing their precision', u'Why is apply not being applied', u'kNN Classifier - importance of DataFrame column order - is this a scikit bug, pandas bug or by design?', u'Why can I not always import pandas', u'Rearrange the columns of a pandas DataFrame so that the column with highest total is first', u'Add 3 columns to DataFrame via map', u'Merge DataFrames based on index columns', u'Inserting columns to existing DataFrame']
#
#
# User 344286 with weightage = 718 >>> Question:
#
# [u'How do I compute the counts of one column based on the values of two others in Pandas?']
#
#
# User 712997 with weightage = 473 >>> Question:
#
# [u'Subplots with groupby DataFrame in pandas?']
#
#
# User 854739 with weightage = 440 >>> Question:
#
# [u'Pandas merge not keeping &#39;on&#39; column', u'In pandas, set a new column and update existing column', u'Pandas Groupby - naming aggregate output column']
#
#
# User 557067 with weightage = 395 >>> Question:
#
# [u'pandas.DataFrame: mappings a column of a list of keys to a column of the list of values']

# %% [markdown]
# # Analysis 2:
#
# ## Steps:
#    1. For each of the User ID that you have collected, ping the API to get all the tags that user has identified with. Here, we use */user/{ids}/tags* method to get the data. Then we save it. *get_id_tags* function is defined to serve this purpose. *id_tag* gives a dictionary in which the user IDs are keys and tags for each user are values.
#    2. Creat a file for each topic, containing user_id, user_name and link to their profile sorted by reputation. *get_user_profile* gives a dictionary which contains the user_name, link, and reputation of each user ID. *topic_user* is also defined to show the users who used each tag sorted by their reputation.
#    3. For a given topic (say python), what are the top users who have reputation in that topic. *top_users_tag* prints out the first or the first two top users who are reputated in a specified topic.

# %%
def get_id_tags(user_id_list):
    
    query = 'users'
    
    new_results = []
    
    for i in range(len(user_id_list)):
    
        key = 'Q8FdL9ZUYfXOw74bF8Q9Wg(('
        page = 1

        url = 'https://api.stackexchange.com/2.2/'+query+'/'+user_id_list[i]+'/tags'+'/?key='+key+'&page='+str(page)+'&pagesize=100'+ \
        '&order=desc&sort=popular&site=stackoverflow'
        

        results = requests.get(url).json()
        new_results += results['items']


        while results['has_more']==True:

            page+=1
            print page
            url = 'https://api.stackexchange.com/2.2/'+query+'/'+user_id_list[i]+'/tags'+'/?key='+key+'&page='+str(page)+'&pagesize=100'+ \
            '&order=desc&sort=popular&site=stackoverflow'
            results = requests.get(url).json()
            new_results += results['items']

    path = query+'tags'
    with open(path+'.json', 'w') as file_out :
            json.dump(new_results, file_out,indent=2)

# %%
#Find and store the data.

get_id_tags(user_batch)

# %%
#Read the data.

data_user_tag = read_data('userstags.json')

# %%
def id_tag(data):
    
    ids_tags = {}
    
    for i in range(len(data)):
        ids_tags.setdefault(data[i]['user_id'],set())
        ids_tags[data[i]['user_id']].add(data[i]['name'])
        
    return ids_tags

# %%
ids_tags = id_tag(data_user_tag)

# %%
#For example, the tags associated with user_id : 53468 look like this:

ids_tags[53468]
# Out:
# {u'apt-get',
#  u'archive',
#  u'ascii-art',
#  u'astyle',
#  u'autocorrect',
#  u'backbone.js',
#  u'bdd',
#  u'benchmarking',
#  u'bottle',
#  u'bug-tracking',
#  u'build',
#  u'c++',
#  u'cascading',
#  u'constructor',
#  u'coverage.py',
#  u'cross-validation',
#  u'date',
#  u'dayofweek',
#  u'dependency-management',
#  u'depth',
#  u'dictionary',
#  u'dita',
#  u'django',
#  u'django-apps',
#  u'django-forms',
#  u'django-mptt',
#  u'django-sites',
#  u'django-socialauth',
#  u'django-templates',
#  u'django-urls',
#  u'docker',
#  u'documentation',
#  u'dumpdata',
#  u'ecmascript-6',
#  u'elasticsearch',
#  u'embedded-linux',
#  u'entry-point',
#  u'environment-variables',
#  u'exception',
#  u'exception-handling',
#  u'fabric',
#  u'facebook',
#  u'facebook-php-sdk',
#  u'fieldset',
#  u'flask',
#  u'form-fields',
#  u'forms',
#  u'geodjango',
#  u'gil',
#  u'global-variables',
#  u'gradle',
#  u'group-by',
#  u'hadoop',
#  u'hdfs',
#  u'higher-order-functions',
#  u'http',
#  u'httperf',
#  u'inspectdb',
#  u'java',
#  u'jinja2',
#  u'jquery',
#  u'json',
#  u'latitude-longitude',
#  u'machine-learning',
#  u'main',
#  u'map',
#  u'memory',
#  u'mercurial',
#  u'mocking',
#  u'mod-wsgi',
#  u'model',
#  u'mongodb',
#  u'mongoengine',
#  u'multithreading',
#  u'mustache',
#  u'mysql',
#  u'nlp',
#  u'offline',
#  u'optparse',
#  u'packages',
#  u'pandas',
#  u'php',
#  u'pip',
#  u'pipe',
#  u'popen',
#  u'postgis',
#  u'project-management',
#  u'pyparsing',
#  u'python',
#  u'python-3.x',
#  u'python-asyncio',
#  u'python-sphinx',
#  u'qt',
#  u'quota',
#  u'react-dom',
#  u'reactjs',
#  u'redirect',
#  u'regex',
#  u'resolve',
#  u'rest',
#  u'restructuredtext',
#  u'scala',
#  u'scalding',
#  u'scikit-learn',
#  u'scons',
#  u'setuptools',
#  u'signals',
#  u'sklearn-pandas',
#  u'sql',
#  u'standards',
#  u'templates',
#  u'testng',
#  u'text-segmentation',
#  u'textarea',
#  u'tornado',
#  u'trac',
#  u'traversal',
#  u'tsv',
#  u'ubuntu-12.04',
#  u'unit-testing',
#  u'upload',
#  u'url-routing',
#  u'virtualenv',
#  u'wkt',
#  u'xml'}

# %%
def get_user_profile(data):
    user_pro = {}
    for i in range(len(data)):
        user_pro.setdefault(data[i]['user_id'],{})
        user_pro[data[i]['user_id']] = {'reputation': data[i]['reputation'],'user_name':data[i]['display_name'],'link':data[i]['link']}
        
    return user_pro

# %%
# We use *data_user_badge_count* that we stored in Analysis 1.

user_profiles = get_user_profile(data_user_badge_count)

# %%
#For example, the profile associated with user_id : 53468 looks like this:

user_profiles[53468]
# Out:
# {'link': u'http://stackoverflow.com/users/53468/tutuca',
#  'reputation': 899,
#  'user_name': u'tutuca'}

# %%
def topic_user(data,user_profiles):

    topic_ids = {}
    
    for i in range(len(data)):

        topic_ids.setdefault(data[i]['name'],{})
        topic_ids[data[i]['name']][data[i]['user_id']] = user_profiles[data[i]['user_id']]
        
    #Sort the values in the dictionary based on the reputatio of each user.
    
    for i in topic_ids:
        
        sorted_val = sorted(topic_ids[i].items(), key = lambda x: x[1]['reputation'], reverse=True)
        topic_ids[i]=(sorted_val)
        
    return topic_ids

# %%
topics_users = topic_user(data_user_tag,user_profiles)

# %%
#This how  the results look like for topic : python

topics_users['python']
# Out:
# [(344286,
#   {'link': u'http://stackoverflow.com/users/344286/wayne-werner',
#    'reputation': 19239,
#    'user_name': u'Wayne Werner'}),
#  (1179880,
#   {'link': u'http://stackoverflow.com/users/1179880/whytheq',
#    'reputation': 14742,
#    'user_name': u'whytheq'}),
#  (237696,
#   {'link': u'http://stackoverflow.com/users/237696/mr-sk',
#    'reputation': 7849,
#    'user_name': u'mr-sk'}),
#  (557067,
#   {'link': u'http://stackoverflow.com/users/557067/xiaohan2012',
#    'reputation': 2147,
#    'user_name': u'xiaohan2012'}),
#  (712997,
#   {'link': u'http://stackoverflow.com/users/712997/lollercoaster',
#    'reputation': 2120,
#    'user_name': u'lollercoaster'}),
#  (680232,
#   {'link': u'http://stackoverflow.com/users/680232/k-michael-aye',
#    'reputation': 2003,
#    'user_name': u'K.-Michael Aye'}),
#  (854739,
#   {'link': u'http://stackoverflow.com/users/854739/mikebmassey',
#    'reputation': 1933,
#    'user_name': u'mikebmassey'}),
#  (1245262,
#   {'link': u'http://stackoverflow.com/users/1245262/user1245262',
#    'reputation': 1883,
#    'user_name': u'user1245262'}),
#  (845169,
#   {'link': u'http://stackoverflow.com/users/845169/leonsas',
#    'reputation': 1660,
#    'user_name': u'leonsas'}),
#  (852063,
#   {'link': u'http://stackoverflow.com/users/852063/amani',
#    'reputation': 1196,
#    'user_name': u'Amani'}),
#  (327702,
#   {'link': u'http://stackoverflow.com/users/327702/opensourcegeek',
#    'reputation': 1179,
#    'user_name': u'opensourcegeek'}),
#  (3596337,
#   {'link': u'http://stackoverflow.com/users/3596337/keiv-fly',
#    'reputation': 1098,
#    'user_name': u'keiv.fly'}),
#  (2457744,
#   {'link': u'http://stackoverflow.com/users/2457744/j-wang',
#    'reputation': 1098,
#    'user_name': u'J Wang'}),
#  (4168397,
#   {'link': u'http://stackoverflow.com/users/4168397/rakesh-adk7',
#    'reputation': 1077,
#    'user_name': u'Rakesh Adk7'}),
#  (1155323,
#   {'link': u'http://stackoverflow.com/users/1155323/adrian',
#    'reputation': 1024,
#    'user_name': u'adrian'}),
#  (3760132,
#   {'link': u'http://stackoverflow.com/users/3760132/banach-tarski',
#    'reputation': 950,
#    'user_name': u'Banach Tarski'}),
#  (860271,
#   {'link': u'http://stackoverflow.com/users/860271/zsljulius',
#    'reputation': 947,
#    'user_name': u'zsljulius'}),
#  (53468,
#   {'link': u'http://stackoverflow.com/users/53468/tutuca',
#    'reputation': 899,
#    'user_name': u'tutuca'}),
#  (2023745,
#   {'link': u'http://stackoverflow.com/users/2023745/alanh',
#    'reputation': 889,
#    'user_name': u'AlanH'}),
#  (1745038,
#   {'link': u'http://stackoverflow.com/users/1745038/an6u5',
#    'reputation': 852,
#    'user_name': u'AN6U5'}),
#  (4698759,
#   {'link': u'http://stackoverflow.com/users/4698759/spicyclubsauce',
#    'reputation': 796,
#    'user_name': u'SpicyClubSauce'}),
#  (3948664,
#   {'link': u'http://stackoverflow.com/users/3948664/dhruv-ghulati',
#    'reputation': 652,
#    'user_name': u'Dhruv Ghulati'}),
#  (819330,
#   {'link': u'http://stackoverflow.com/users/819330/nikosdi',
#    'reputation': 575,
#    'user_name': u'nikosdi'}),
#  (2227093,
#   {'link': u'http://stackoverflow.com/users/2227093/vhd',
#    'reputation': 536,
#    'user_name': u'vhd'}),
#  (1687633,
#   {'link': u'http://stackoverflow.com/users/1687633/killersnail',
#    'reputation': 527,
#    'user_name': u'KillerSnail'}),
#  (5537840,
#   {'link': u'http://stackoverflow.com/users/5537840/roma-karageorgievich',
#    'reputation': 509,
#    'user_name': u'Roma  Karageorgievich'}),
#  (1119602,
#   {'link': u'http://stackoverflow.com/users/1119602/winand',
#    'reputation': 509,
#    'user_name': u'Winand'}),
#  (945738,
#   {'link': u'http://stackoverflow.com/users/945738/armando',
#    'reputation': 467,
#    'user_name': u'armando'}),
#  (909515,
#   {'link': u'http://stackoverflow.com/users/909515/matt-warren',
#    'reputation': 427,
#    'user_name': u'Matt Warren'}),
#  (532570,
#   {'link': u'http://stackoverflow.com/users/532570/toast',
#    'reputation': 402,
#    'user_name': u'toast'}),
#  (2605262,
#   {'link': u'http://stackoverflow.com/users/2605262/lukasz',
#    'reputation': 401,
#    'user_name': u'Lukasz'}),
#  (2539738,
#   {'link': u'http://stackoverflow.com/users/2539738/user2539738',
#    'reputation': 383,
#    'user_name': u'user2539738'}),
#  (3842102,
#   {'link': u'http://stackoverflow.com/users/3842102/baconwichsand',
#    'reputation': 355,
#    'user_name': u'baconwichsand'}),
#  (4931657,
#   {'link': u'http://stackoverflow.com/users/4931657/jake-wong',
#    'reputation': 341,
#    'user_name': u'jake wong'}),
#  (1908806,
#   {'link': u'http://stackoverflow.com/users/1908806/sheridan-gray',
#    'reputation': 336,
#    'user_name': u'Sheridan Gray'}),
#  (4005915,
#   {'link': u'http://stackoverflow.com/users/4005915/nathan-clement',
#    'reputation': 335,
#    'user_name': u'Nathan Clement'}),
#  (4972716,
#   {'link': u'http://stackoverflow.com/users/4972716/stacey',
#    'reputation': 332,
#    'user_name': u'Stacey'}),
#  (2965673,
#   {'link': u'http://stackoverflow.com/users/2965673/adam',
#    'reputation': 330,
#    'user_name': u'Adam'}),
#  (5759063,
#   {'link': u'http://stackoverflow.com/users/5759063/sreejith-menon',
#    'reputation': 323,
#    'user_name': u'Sreejith Menon'}),
#  (2400377,
#   {'link': u'http://stackoverflow.com/users/2400377/nicolekanderson',
#    'reputation': 323,
#    'user_name': u'nicolekanderson'}),
#  (3768495,
#   {'link': u'http://stackoverflow.com/users/3768495/user3768495',
#    'reputation': 323,
#    'user_name': u'user3768495'}),
#  (2301970,
#   {'link': u'http://stackoverflow.com/users/2301970/delosari',
#    'reputation': 322,
#    'user_name': u'Delosari'}),
#  (5366046,
#   {'link': u'http://stackoverflow.com/users/5366046/sundong',
#    'reputation': 313,
#    'user_name': u'SUNDONG'}),
#  (3407933,
#   {'link': u'http://stackoverflow.com/users/3407933/spacetyper',
#    'reputation': 260,
#    'user_name': u'spacetyper'}),
#  (3457053,
#   {'link': u'http://stackoverflow.com/users/3457053/user137425',
#    'reputation': 248,
#    'user_name': u'user137425'}),
#  (4169892,
#   {'link': u'http://stackoverflow.com/users/4169892/maryam-pashmi',
#    'reputation': 214,
#    'user_name': u'Maryam Pashmi'}),
#  (565514,
#   {'link': u'http://stackoverflow.com/users/565514/dan-steingart',
#    'reputation': 190,
#    'user_name': u'Dan Steingart'}),
#  (2962786,
#   {'link': u'http://stackoverflow.com/users/2962786/datatx',
#    'reputation': 184,
#    'user_name': u'DataTx'}),
#  (3136924,
#   {'link': u'http://stackoverflow.com/users/3136924/alexstarbuck',
#    'reputation': 179,
#    'user_name': u'AlexStarbuck'}),
#  (5890240,
#   {'link': u'http://stackoverflow.com/users/5890240/nikolai',
#    'reputation': 178,
#    'user_name': u'Nikolai'}),
#  (3875107,
#   {'link': u'http://stackoverflow.com/users/3875107/ds-user',
#    'reputation': 165,
#    'user_name': u'ds_user'}),
#  (4661264,
#   {'link': u'http://stackoverflow.com/users/4661264/sushovan-mandal',
#    'reputation': 158,
#    'user_name': u'Sushovan Mandal'}),
#  (4333609,
#   {'link': u'http://stackoverflow.com/users/4333609/kenny',
#    'reputation': 151,
#    'user_name': u'Kenny'}),
#  (3817518,
#   {'link': u'http://stackoverflow.com/users/3817518/user3817518',
#    'reputation': 150,
#    'user_name': u'user3817518'}),
#  (2965601,
#   {'link': u'http://stackoverflow.com/users/2965601/tumbler',
#    'reputation': 150,
#    'user_name': u'tumbler'}),
#  (3072050,
#   {'link': u'http://stackoverflow.com/users/3072050/bayerse',
#    'reputation': 144,
#    'user_name': u'BayerSe'}),
#  (5283845,
#   {'link': u'http://stackoverflow.com/users/5283845/joe-law',
#    'reputation': 138,
#    'user_name': u'Joe Law'}),
#  (5063127,
#   {'link': u'http://stackoverflow.com/users/5063127/observer',
#    'reputation': 134,
#    'user_name': u'Observer'}),
#  (4661552,
#   {'link': u'http://stackoverflow.com/users/4661552/jason-ching-yuk',
#    'reputation': 125,
#    'user_name': u'Jason Ching Yuk'}),
#  (3637548,
#   {'link': u'http://stackoverflow.com/users/3637548/b-furtado',
#    'reputation': 121,
#    'user_name': u'B_Furtado'}),
#  (2696565,
#   {'link': u'http://stackoverflow.com/users/2696565/user2696565',
#    'reputation': 119,
#    'user_name': u'user2696565'}),
#  (5505161,
#   {'link': u'http://stackoverflow.com/users/5505161/lordingtar',
#    'reputation': 114,
#    'user_name': u'lordingtar'}),
#  (549094,
#   {'link': u'http://stackoverflow.com/users/549094/robinho',
#    'reputation': 113,
#    'user_name': u'Robinho'}),
#  (4055335,
#   {'link': u'http://stackoverflow.com/users/4055335/nirvan-sengupta',
#    'reputation': 113,
#    'user_name': u'Nirvan Sengupta'}),
#  (5906433,
#   {'link': u'http://stackoverflow.com/users/5906433/mailman-73',
#    'reputation': 112,
#    'user_name': u'mailman_73'}),
#  (3686493,
#   {'link': u'http://stackoverflow.com/users/3686493/pan0ramic',
#    'reputation': 111,
#    'user_name': u'pan0ramic'}),
#  (5563746,
#   {'link': u'http://stackoverflow.com/users/5563746/menkes',
#    'reputation': 109,
#    'user_name': u'Menkes'}),
#  (5112031,
#   {'link': u'http://stackoverflow.com/users/5112031/nbckly',
#    'reputation': 108,
#    'user_name': u'NBCKLY'}),
#  (4866196,
#   {'link': u'http://stackoverflow.com/users/4866196/fuzunspm',
#    'reputation': 104,
#    'user_name': u'fuzunspm'}),
#  (5491423,
#   {'link': u'http://stackoverflow.com/users/5491423/peter-b',
#    'reputation': 102,
#    'user_name': u'Peter B.'}),
#  (1777919,
#   {'link': u'http://stackoverflow.com/users/1777919/saranya-krishnamurthy',
#    'reputation': 101,
#    'user_name': u'Saranya Krishnamurthy'}),
#  (2277435,
#   {'link': u'http://stackoverflow.com/users/2277435/user2277435',
#    'reputation': 100,
#    'user_name': u'user2277435'}),
#  (5374161,
#   {'link': u'http://stackoverflow.com/users/5374161/krishanu-konar',
#    'reputation': 99,
#    'user_name': u'Krishanu Konar'}),
#  (6545542,
#   {'link': u'http://stackoverflow.com/users/6545542/christopher',
#    'reputation': 96,
#    'user_name': u'Christopher'}),
#  (4098013,
#   {'link': u'http://stackoverflow.com/users/4098013/vivek-kalyanarangan',
#    'reputation': 96,
#    'user_name': u'Vivek Kalyanarangan'}),
#  (4334596,
#   {'link': u'http://stackoverflow.com/users/4334596/dima',
#    'reputation': 89,
#    'user_name': u'Dima'}),
#  (3490069,
#   {'link': u'http://stackoverflow.com/users/3490069/minos',
#    'reputation': 83,
#    'user_name': u'Minos'}),
#  (3121439,
#   {'link': u'http://stackoverflow.com/users/3121439/rubito',
#    'reputation': 81,
#    'user_name': u'rubito'}),
#  (1946989,
#   {'link': u'http://stackoverflow.com/users/1946989/user1946989',
#    'reputation': 80,
#    'user_name': u'user1946989'}),
#  (2408643,
#   {'link': u'http://stackoverflow.com/users/2408643/puja',
#    'reputation': 77,
#    'user_name': u'PUJA'}),
#  (5112032,
#   {'link': u'http://stackoverflow.com/users/5112032/eljusticiero67',
#    'reputation': 76,
#    'user_name': u'eljusticiero67'}),
#  (4317363,
#   {'link': u'http://stackoverflow.com/users/4317363/asdf',
#    'reputation': 75,
#    'user_name': u'asdf'}),
#  (6470353,
#   {'link': u'http://stackoverflow.com/users/6470353/sle',
#    'reputation': 75,
#    'user_name': u'SLE'}),
#  (6267003,
#   {'link': u'http://stackoverflow.com/users/6267003/obabs',
#    'reputation': 73,
#    'user_name': u'obabs'}),
#  (2564199,
#   {'link': u'http://stackoverflow.com/users/2564199/pauline',
#    'reputation': 66,
#    'user_name': u'Pauline'}),
#  (4789642,
#   {'link': u'http://stackoverflow.com/users/4789642/rodrigo-matus-nicodemos',
#    'reputation': 66,
#    'user_name': u'Rodrigo Matus-Nicodemos'}),
#  (4111026,
#   {'link': u'http://stackoverflow.com/users/4111026/jake',
#    'reputation': 65,
#    'user_name': u'Jake'}),
#  (6136013,
#   {'link': u'http://stackoverflow.com/users/6136013/blinddriver',
#    'reputation': 65,
#    'user_name': u'BlindDriver'}),
#  (6635802,
#   {'link': u'http://stackoverflow.com/users/6635802/mmeclimate',
#    'reputation': 64,
#    'user_name': u'mmeclimate'}),
#  (6316050,
#   {'link': u'http://stackoverflow.com/users/6316050/bio',
#    'reputation': 58,
#    'user_name': u'Bio'}),
#  (5115928,
#   {'link': u'http://stackoverflow.com/users/5115928/sechstein',
#    'reputation': 56,
#    'user_name': u'sechstein'}),
#  (5488652,
#   {'link': u'http://stackoverflow.com/users/5488652/user5488652',
#    'reputation': 55,
#    'user_name': u'user5488652'}),
#  (2605182,
#   {'link': u'http://stackoverflow.com/users/2605182/rocket-raccoon',
#    'reputation': 54,
#    'user_name': u'rocket_raccoon'}),
#  (4388195,
#   {'link': u'http://stackoverflow.com/users/4388195/j-a-cado',
#    'reputation': 54,
#    'user_name': u'J.A.Cado'}),
#  (4444452,
#   {'link': u'http://stackoverflow.com/users/4444452/nero',
#    'reputation': 51,
#    'user_name': u'Nero'}),
#  (2608081,
#   {'link': u'http://stackoverflow.com/users/2608081/rontho1992',
#    'reputation': 51,
#    'user_name': u'rontho1992'}),
#  (2621477,
#   {'link': u'http://stackoverflow.com/users/2621477/chandu',
#    'reputation': 50,
#    'user_name': u'chandu'}),
#  (5652674,
#   {'link': u'http://stackoverflow.com/users/5652674/jammy',
#    'reputation': 50,
#    'user_name': u'Jammy'}),
#  (2728074,
#   {'link': u'http://stackoverflow.com/users/2728074/charlie',
#    'reputation': 49,
#    'user_name': u'Charlie'}),
#  (2711738,
#   {'link': u'http://stackoverflow.com/users/2711738/alexabate',
#    'reputation': 48,
#    'user_name': u'alexabate'}),
#  (4750039,
#   {'link': u'http://stackoverflow.com/users/4750039/muhammad-waseem',
#    'reputation': 46,
#    'user_name': u'muhammad waseem'}),
#  (3399944,
#   {'link': u'http://stackoverflow.com/users/3399944/swmfg',
#    'reputation': 43,
#    'user_name': u'swmfg'}),
#  (3358138,
#   {'link': u'http://stackoverflow.com/users/3358138/dirk',
#    'reputation': 43,
#    'user_name': u'dirk'}),
#  (5468983,
#   {'link': u'http://stackoverflow.com/users/5468983/sherlock',
#    'reputation': 42,
#    'user_name': u'Sherlock'}),
#  (5742819,
#   {'link': u'http://stackoverflow.com/users/5742819/varsha',
#    'reputation': 41,
#    'user_name': u'Varsha '}),
#  (5906506,
#   {'link': u'http://stackoverflow.com/users/5906506/tom-krakov',
#    'reputation': 36,
#    'user_name': u'Tom Krakov'}),
#  (6275292,
#   {'link': u'http://stackoverflow.com/users/6275292/avicohen',
#    'reputation': 36,
#    'user_name': u'avicohen'}),
#  (5431568,
#   {'link': u'http://stackoverflow.com/users/5431568/charles',
#    'reputation': 35,
#    'user_name': u'Charles'}),
#  (4751525,
#   {'link': u'http://stackoverflow.com/users/4751525/kemal-diri',
#    'reputation': 34,
#    'user_name': u'Kemal Diri'}),
#  (3932482,
#   {'link': u'http://stackoverflow.com/users/3932482/siva-gabbi',
#    'reputation': 34,
#    'user_name': u'Siva.Gabbi'}),
#  (6645104,
#   {'link': u'http://stackoverflow.com/users/6645104/dagg3r',
#    'reputation': 34,
#    'user_name': u'dagg3r'}),
#  (3285014,
#   {'link': u'http://stackoverflow.com/users/3285014/user3285014',
#    'reputation': 33,
#    'user_name': u'user3285014'}),
#  (1253493,
#   {'link': u'http://stackoverflow.com/users/1253493/user1253493',
#    'reputation': 32,
#    'user_name': u'user1253493'}),
#  (5519631,
#   {'link': u'http://stackoverflow.com/users/5519631/beng986',
#    'reputation': 32,
#    'user_name': u'beng986'}),
#  (5331808,
#   {'link': u'http://stackoverflow.com/users/5331808/tdunham28',
#    'reputation': 32,
#    'user_name': u'tdunham28'}),
#  (3981355,
#   {'link': u'http://stackoverflow.com/users/3981355/carlos-arronte-bello',
#    'reputation': 31,
#    'user_name': u'Carlos Arronte Bello'}),
#  (1736893,
#   {'link': u'http://stackoverflow.com/users/1736893/sunil',
#    'reputation': 31,
#    'user_name': u'Sunil'}),
#  (1785871,
#   {'link': u'http://stackoverflow.com/users/1785871/danwise',
#    'reputation': 30,
#    'user_name': u'Danwise'}),
#  (3997814,
#   {'link': u'http://stackoverflow.com/users/3997814/travis-millburn',
#    'reputation': 30,
#    'user_name': u'Travis Millburn'}),
#  (6585004,
#   {'link': u'http://stackoverflow.com/users/6585004/bshuniversity',
#    'reputation': 29,
#    'user_name': u'BSHuniversity'}),
#  (5559673,
#   {'link': u'http://stackoverflow.com/users/5559673/aquaelmo',
#    'reputation': 29,
#    'user_name': u'aquaelmo'}),
#  (6692870,
#   {'link': u'http://stackoverflow.com/users/6692870/gauss-lee',
#    'reputation': 28,
#    'user_name': u'Gauss Lee'}),
#  (6455328,
#   {'link': u'http://stackoverflow.com/users/6455328/wowdavers',
#    'reputation': 28,
#    'user_name': u'wowdavers'}),
#  (6462497,
#   {'link': u'http://stackoverflow.com/users/6462497/xan',
#    'reputation': 28,
#    'user_name': u'xan'}),
#  (3473471,
#   {'link': u'http://stackoverflow.com/users/3473471/labrynth',
#    'reputation': 28,
#    'user_name': u'labrynth'}),
#  (6646464,
#   {'link': u'http://stackoverflow.com/users/6646464/davinci',
#    'reputation': 27,
#    'user_name': u'DaVinci'}),
#  (6537508,
#   {'link': u'http://stackoverflow.com/users/6537508/hsquared',
#    'reputation': 26,
#    'user_name': u'hsquared'}),
#  (5744566,
#   {'link': u'http://stackoverflow.com/users/5744566/beginner',
#    'reputation': 26,
#    'user_name': u'beginner'}),
#  (6561949,
#   {'link': u'http://stackoverflow.com/users/6561949/aaron',
#    'reputation': 25,
#    'user_name': u'Aaron'}),
#  (5865631,
#   {'link': u'http://stackoverflow.com/users/5865631/alemosie',
#    'reputation': 25,
#    'user_name': u'alemosie'}),
#  (5865585,
#   {'link': u'http://stackoverflow.com/users/5865585/chan-austin',
#    'reputation': 24,
#    'user_name': u'Chan Austin'}),
#  (5595316,
#   {'link': u'http://stackoverflow.com/users/5595316/hassam-sheikh',
#    'reputation': 24,
#    'user_name': u'Hassam Sheikh'}),
#  (3357137,
#   {'link': u'http://stackoverflow.com/users/3357137/francisco-soc%c3%adas',
#    'reputation': 24,
#    'user_name': u'francisco soc&#237;as'}),
#  (1687586,
#   {'link': u'http://stackoverflow.com/users/1687586/tmgolf',
#    'reputation': 23,
#    'user_name': u'tmgolf'}),
#  (5521530,
#   {'link': u'http://stackoverflow.com/users/5521530/john',
#    'reputation': 23,
#    'user_name': u'John'}),
#  (3178680,
#   {'link': u'http://stackoverflow.com/users/3178680/user3178680',
#    'reputation': 23,
#    'user_name': u'user3178680'}),
#  (4350205,
#   {'link': u'http://stackoverflow.com/users/4350205/burner',
#    'reputation': 22,
#    'user_name': u'Burner'}),
#  (5660947,
#   {'link': u'http://stackoverflow.com/users/5660947/jingtao-yun',
#    'reputation': 22,
#    'user_name': u'Jingtao Yun'}),
#  (6185262,
#   {'link': u'http://stackoverflow.com/users/6185262/altsheets',
#    'reputation': 22,
#    'user_name': u'AltSheets'}),
#  (5660808,
#   {'link': u'http://stackoverflow.com/users/5660808/the-user',
#    'reputation': 21,
#    'user_name': u'The User'}),
#  (5759224,
#   {'link': u'http://stackoverflow.com/users/5759224/mat-s',
#    'reputation': 21,
#    'user_name': u'Mat S'}),
#  (3784956,
#   {'link': u'http://stackoverflow.com/users/3784956/user3784956',
#    'reputation': 21,
#    'user_name': u'user3784956'}),
#  (3956899,
#   {'link': u'http://stackoverflow.com/users/3956899/mari',
#    'reputation': 20,
#    'user_name': u'Mari'}),
#  (3334415,
#   {'link': u'http://stackoverflow.com/users/3334415/user3334415',
#    'reputation': 20,
#    'user_name': u'user3334415'}),
#  (5213098,
#   {'link': u'http://stackoverflow.com/users/5213098/f-r',
#    'reputation': 20,
#    'user_name': u'F. R'}),
#  (6168738,
#   {'link': u'http://stackoverflow.com/users/6168738/ankit-jain',
#    'reputation': 19,
#    'user_name': u'ankit jain'}),
#  (6242372,
#   {'link': u'http://stackoverflow.com/users/6242372/jimmy',
#    'reputation': 18,
#    'user_name': u'Jimmy'}),
#  (6201445,
#   {'link': u'http://stackoverflow.com/users/6201445/ak-1',
#    'reputation': 18,
#    'user_name': u'ak_1'}),
#  (5544925,
#   {'link': u'http://stackoverflow.com/users/5544925/macavich',
#    'reputation': 18,
#    'user_name': u'macavich'}),
#  (3022867,
#   {'link': u'http://stackoverflow.com/users/3022867/john-everyman',
#    'reputation': 16,
#    'user_name': u'John_Everyman'}),
#  (6414357,
#   {'link': u'http://stackoverflow.com/users/6414357/paramjeet',
#    'reputation': 16,
#    'user_name': u'paramjeet'}),
#  (6111318,
#   {'link': u'http://stackoverflow.com/users/6111318/ian-m',
#    'reputation': 16,
#    'user_name': u'Ian M'}),
#  (2195729,
#   {'link': u'http://stackoverflow.com/users/2195729/marcel',
#    'reputation': 15,
#    'user_name': u'Marcel'}),
#  (5390612,
#   {'link': u'http://stackoverflow.com/users/5390612/michael',
#    'reputation': 14,
#    'user_name': u'Michael'}),
#  (6070332,
#   {'link': u'http://stackoverflow.com/users/6070332/myriad',
#    'reputation': 13,
#    'user_name': u'myriad'}),
#  (6529115,
#   {'link': u'http://stackoverflow.com/users/6529115/c-stucki',
#    'reputation': 13,
#    'user_name': u'C. Stucki'}),
#  (6291581,
#   {'link': u'http://stackoverflow.com/users/6291581/henryb',
#    'reputation': 13,
#    'user_name': u'HenryB'}),
#  (6733959,
#   {'link': u'http://stackoverflow.com/users/6733959/kubik-straka',
#    'reputation': 13,
#    'user_name': u'Kubik Straka'}),
#  (6118101,
#   {'link': u'http://stackoverflow.com/users/6118101/mrpool',
#    'reputation': 13,
#    'user_name': u'MrPool'}),
#  (4383027,
#   {'link': u'http://stackoverflow.com/users/4383027/solonome',
#    'reputation': 12,
#    'user_name': u'solonome'}),
#  (6217748,
#   {'link': u'http://stackoverflow.com/users/6217748/raphael-prinz',
#    'reputation': 11,
#    'user_name': u'Raphael Prinz'}),
#  (6684916,
#   {'link': u'http://stackoverflow.com/users/6684916/carol-z',
#    'reputation': 11,
#    'user_name': u'Carol.Z'}),
#  (5812577,
#   {'link': u'http://stackoverflow.com/users/5812577/dbk12345',
#    'reputation': 11,
#    'user_name': u'dbk12345'}),
#  (3144099,
#   {'link': u'http://stackoverflow.com/users/3144099/christian-yeah',
#    'reputation': 11,
#    'user_name': u'Christian_yeah'}),
#  (6801842,
#   {'link': u'http://stackoverflow.com/users/6801842/markj',
#    'reputation': 11,
#    'user_name': u'markj'}),
#  (6488274,
#   {'link': u'http://stackoverflow.com/users/6488274/thomas2004ch',
#    'reputation': 10,
#    'user_name': u'thomas2004ch'}),
#  (6291465,
#   {'link': u'http://stackoverflow.com/users/6291465/nycted',
#    'reputation': 8,
#    'user_name': u'NYCTed'}),
#  (6373432,
#   {'link': u'http://stackoverflow.com/users/6373432/djtama',
#    'reputation': 8,
#    'user_name': u'djtama'}),
#  (6889536,
#   {'link': u'http://stackoverflow.com/users/6889536/david',
#    'reputation': 8,
#    'user_name': u'David'}),
#  (6037573,
#   {'link': u'http://stackoverflow.com/users/6037573/allen-h',
#    'reputation': 8,
#    'user_name': u'Allen H'}),
#  (6639629,
#   {'link': u'http://stackoverflow.com/users/6639629/travis1585',
#    'reputation': 8,
#    'user_name': u'Travis1585'}),
#  (5619902,
#   {'link': u'http://stackoverflow.com/users/5619902/shikshaw-reincarnates',
#    'reputation': 8,
#    'user_name': u'shikshaw reincarnates'}),
#  (1433643,
#   {'link': u'http://stackoverflow.com/users/1433643/golden-rum',
#    'reputation': 8,
#    'user_name': u'golden.rum'}),
#  (6881578,
#   {'link': u'http://stackoverflow.com/users/6881578/pigfoot',
#    'reputation': 8,
#    'user_name': u'PigFoot'}),
#  (4810108,
#   {'link': u'http://stackoverflow.com/users/4810108/threefrenchhens',
#    'reputation': 8,
#    'user_name': u'threefrenchhens'}),
#  (6758413,
#   {'link': u'http://stackoverflow.com/users/6758413/seedofabraham',
#    'reputation': 6,
#    'user_name': u'seedofabraham'}),
#  (3714634,
#   {'link': u'http://stackoverflow.com/users/3714634/user3714634',
#    'reputation': 6,
#    'user_name': u'user3714634'}),
#  (1998919,
#   {'link': u'http://stackoverflow.com/users/1998919/brett-addison',
#    'reputation': 6,
#    'user_name': u'Brett Addison'}),
#  (6529170,
#   {'link': u'http://stackoverflow.com/users/6529170/tarun',
#    'reputation': 6,
#    'user_name': u'Tarun'}),
#  (7069877,
#   {'link': u'http://stackoverflow.com/users/7069877/zhelyu',
#    'reputation': 6,
#    'user_name': u'zhelyu'}),
#  (5390557,
#   {'link': u'http://stackoverflow.com/users/5390557/c-rogers',
#    'reputation': 6,
#    'user_name': u'C. Rogers'}),
#  (6199534,
#   {'link': u'http://stackoverflow.com/users/6199534/simonz',
#    'reputation': 6,
#    'user_name': u'SimonZ'}),
#  (6602969,
#   {'link': u'http://stackoverflow.com/users/6602969/brunda-reddy',
#    'reputation': 6,
#    'user_name': u'Brunda Reddy'}),
#  (7020856,
#   {'link': u'http://stackoverflow.com/users/7020856/user9123',
#    'reputation': 6,
#    'user_name': u'User9123'}),
#  (5232517,
#   {'link': u'http://stackoverflow.com/users/5232517/vixare',
#    'reputation': 6,
#    'user_name': u'Vixare'}),
#  (5552408,
#   {'link': u'http://stackoverflow.com/users/5552408/phebe-wu',
#    'reputation': 4,
#    'user_name': u'phebe wu'}),
#  (6185056,
#   {'link': u'http://stackoverflow.com/users/6185056/ran-zhao',
#    'reputation': 3,
#    'user_name': u'Ran Zhao'}),
#  (5988450,
#   {'link': u'http://stackoverflow.com/users/5988450/alexander-denisenko',
#    'reputation': 3,
#    'user_name': u'Alexander Denisenko'}),
#  (6676599,
#   {'link': u'http://stackoverflow.com/users/6676599/erin-bautista',
#    'reputation': 3,
#    'user_name': u'Erin Bautista'}),
#  (6382972,
#   {'link': u'http://stackoverflow.com/users/6382972/guga',
#    'reputation': 3,
#    'user_name': u'Guga'}),
#  (6176978,
#   {'link': u'http://stackoverflow.com/users/6176978/tiagol',
#    'reputation': 3,
#    'user_name': u'TiagoL'}),
#  (3318023,
#   {'link': u'http://stackoverflow.com/users/3318023/user3318023',
#    'reputation': 3,
#    'user_name': u'user3318023'}),
#  (5443623,
#   {'link': u'http://stackoverflow.com/users/5443623/manish-sharma',
#    'reputation': 1,
#    'user_name': u'Manish Sharma'}),
#  (3715124,
#   {'link': u'http://stackoverflow.com/users/3715124/user329620',
#    'reputation': 1,
#    'user_name': u'user329620'}),
#  (6930507,
#   {'link': u'http://stackoverflow.com/users/6930507/atr4xxas',
#    'reputation': 1,
#    'user_name': u'atr4xxas'}),
#  (6357081,
#   {'link': u'http://stackoverflow.com/users/6357081/user6357081',
#    'reputation': 1,
#    'user_name': u'user6357081'}),
#  (6840427,
#   {'link': u'http://stackoverflow.com/users/6840427/big-ozzy',
#    'reputation': 1,
#    'user_name': u'Big_Ozzy'}),
#  (5947544,
#   {'link': u'http://stackoverflow.com/users/5947544/energyguy',
#    'reputation': 1,
#    'user_name': u'energyguy'}),
#  (6324437,
#   {'link': u'http://stackoverflow.com/users/6324437/kizzle',
#    'reputation': 1,
#    'user_name': u'Kizzle'}),
#  (6537521,
#   {'link': u'http://stackoverflow.com/users/6537521/jkih',
#    'reputation': 1,
#    'user_name': u'jkih'})]

# %%
def top_users_tag(topic, topic_user):
    num_users = len(topic_user[topic])
    if num_users == 1:
        print topic_user[topic][0]
    else:
        print topic_user[topic][0]
        print topic_user[topic][1]

# %%
#First two top users on topic python

top_users_reput_tag = top_users_tag('python', topics_users)
# Out:
# (344286, {'link': u'http://stackoverflow.com/users/344286/wayne-werner', 'reputation': 19239, 'user_name': u'Wayne Werner'})
# (1179880, {'link': u'http://stackoverflow.com/users/1179880/whytheq', 'reputation': 14742, 'user_name': u'whytheq'})

# %% [markdown]
# # Analysis 3:
# ## Steps:
#    1. For each of the badge type, find how many users (based on the data you have collected) have badge. To find the number of badges for each user, we can use the result of Analysis 1. In dictionary *user_id_weightage* the users whose values are zero, have no badges. *users_with_no_badge* finds that number.
#    2. We want to see what badges are popular among the users. *popular badge* counts the number of each type of badges.

# %%
def users_with_no_badge(user_id_weightage):
    
    user_w = dict(user_id_weightage)
    c = 0
    
    for i in user_w:
        if user_w[i]==0:
            c+=1
        else:
            continue
            
    print str(c)+' users out of '+ str(len(user_w))+ ' have no badge'
    return c

# %%
users_no_badge = users_with_no_badge(user_id_weightage)
# Out:
# 4 users out of 200 have no badge

# %%
def popular_badge(data):
    
    num_badge = {'gold':0, 'silver':0, 'bronze':0}
    
    for i in range(len(data)):
        
        num_badge['gold'] += data[i]['badge_counts']['gold']
        num_badge['silver'] += data[i]['badge_counts']['silver']
        num_badge['bronze'] += data[i]['badge_counts']['bronze']
    
    return num_badge

# %%
popular_badges = popular_badge(data_user_badge_count)

# %%
popular_badges

#We can see 'bronze' is the most popular badge among all badges.
# Out:
# {'bronze': 5701, 'gold': 319, 'silver': 1620}

# %% [markdown]
# # Analysis 4:
# ## Steps:
# 1. For each of the question that is asked, find out the tags attached to it. *search_save_question* uses */questions* method to find this data. *all_tags* gives the tags associated with each question in a dictionary format.
# 2. Find how many numbers of answers have been given for each question. For each tag, calculate the number of questions asked and how many times it has been answered. *number_of_answers* gives a dictionary of the questions and the number of answers given to that question. *tag_number_of_questions* and *tag_number_of_answers* will find that for each tag how many questions have been asked, and how many answers given to them, respectively.

# %%
def search_save_question(from_date, to_date):
    
    query = 'questions'
    key = 'Q8FdL9ZUYfXOw74bF8Q9Wg(('                           #This is the key which enables us to have a higher limit to search
    page = 1
    pattern = '%Y %m %d'
    formdate = time_epoch(from_date, pattern) 
    todate = time_epoch(to_date, pattern)
    
    # We need to make the correct url to send a request to StackExchange.
    
    url = 'https://api.stackexchange.com/2.2/'+query+'?key='+key+'&page='+str(page)+'&pagesize=100'+'&fromdate='+fromdate+ \
    '&todate='+todate+'&order=desc&min='+'&sort=activity&site=stackoverflow'
    
    results = requests.get(url).json()
    new_results = results['items']
    
    #Here, we make sure we also get all the data in next pages.
    
    while results['has_more']==True:
        
        page+=1
        print page
        url = 'https://api.stackexchange.com/2.0/'+query+'?key='+key+'&page='+str(page)+'&pagesize=100'+'&fromdate='+fromdate+ \
        '&todate='+todate+'&order=desc&min='+'&sort=activity&site=stackoverflow'
        results = requests.get(url).json()
        new_results += results['items']

    #At the end, we save the data in a json format to do analysis on later.
    
    path = query
    with open(path+'.json', 'w') as file_out :
            json.dump(new_results, file_out,indent=2)

# %%
#Read the data.

data_question_tag = read_data('questionspython;pandas.json')

# %%
def all_tags(data):
    
    all_tags = set()
    
    for i in range(len(data)):
        
        for j in data[i]['tags']:
            all_tags.add(j)
    
    return all_tags

# %%
all_tags_questions = all_tags(data_question_tag)

# %%
all_tags_questions
# Out:
# {u'osx',
#  u'partial',
#  u'iterator',
#  u'similarity',
#  u'duplicates',
#  u'google-spreadsheet-api',
#  u'global',
#  u'dynamic',
#  u'gz',
#  u'pymysql',
#  u'scalar',
#  u'sparse-matrix',
#  u'ggplot2',
#  u'text-classification',
#  u'disk',
#  u'row',
#  u'cython',
#  u'cvxopt',
#  u'typeerror',
#  u'xts',
#  u'flask',
#  u'graph',
#  u'jython-2.7',
#  u'text-extraction',
#  u'strptime',
#  u'clipboard',
#  u'tail',
#  u'multicore',
#  u'swap',
#  u'biopython',
#  u'stochastic',
#  u'nonetype',
#  u'proj',
#  u'division',
#  u'labels',
#  u'string',
#  u'delimited-text',
#  u'vba',
#  u'vlookup',
#  u'map-function',
#  u'runtimeexception',
#  u'with-statement',
#  u'mpi',
#  u'read-write',
#  u'tostring',
#  u'insert-update',
#  u'anonymous',
#  u'difference',
#  u'condition',
#  u'pythonista',
#  u'filepath',
#  u'solver',
#  u'list',
#  u'mapreduce',
#  u'hive',
#  u'string-comparison',
#  u'pearson-correlation',
#  u'vector',
#  u'indices',
#  u'netcdf',
#  u'textedit',
#  u'multiprocessing',
#  u'versioning',
#  u'exxeleron-q',
#  u'datetimeoffset',
#  u'cookies',
#  u'contextmanager',
#  u'cluster-analysis',
#  u'prediction',
#  u'cron',
#  u'kivy',
#  u'download',
#  u'groovy',
#  u'pyodbc',
#  u'operator-overloading',
#  u'html5lib',
#  u'append',
#  u'jupyter-notebook',
#  u'sql-server-2008',
#  u'weighted-average',
#  u'pivot-table',
#  u'groupwise-maximum',
#  u'sum',
#  u'axes',
#  u'rollup',
#  u'beautifulsoup',
#  u'melt',
#  u'uniform',
#  u'access',
#  u'seconds',
#  u'yield-return',
#  u'heatmap',
#  u'helper-functions',
#  u'intersect',
#  u'export-to-excel',
#  u'shared',
#  u'ipad',
#  u'metadata',
#  u'text-files',
#  u'linear-regression',
#  u'hash',
#  u'tags',
#  u'matplotlib',
#  u'dstream',
#  u'influxdb',
#  u'hashtable',
#  u'groups',
#  u'ubuntu',
#  u'apache',
#  u'path',
#  u'legend',
#  u'data-manipulation',
#  u'search',
#  u'frequency-analysis',
#  u'inheritance',
#  u'pytables',
#  u'hdf5',
#  u'shift',
#  u'date-range',
#  u'pythonanywhere',
#  u'expression',
#  u'cross-join',
#  u'rdd',
#  u'delimiter',
#  u'countif',
#  u'rda',
#  u'weekday',
#  u'permutation',
#  u'identity',
#  u'options',
#  u'curve-fitting',
#  u'recursion',
#  u'shuffle',
#  u'divide',
#  u'classification',
#  u'segmentation-fault',
#  u'compare',
#  u'readfile',
#  u'replace',
#  u'unix',
#  u'boolean',
#  u'calculated-columns',
#  u'divmod',
#  u'pretty-print',
#  u'text-analysis',
#  u'chunks',
#  u'apply',
#  u'parameter-passing',
#  u'rollover',
#  u'coercion',
#  u'fixed-width',
#  u'genetic-algorithm',
#  u'plot',
#  u'executable',
#  u'elementtree',
#  u'tar',
#  u'zip',
#  u'google-app-engine',
#  u'distinct',
#  u'carriage-return',
#  u'contains',
#  u'selection',
#  u'training-data',
#  u'next',
#  u'duration',
#  u'datanitro',
#  u'comparison-operators',
#  u'readonly',
#  u'soundcloud',
#  u'memory',
#  u'timing',
#  u'scope',
#  u'datastax',
#  u'genfromtxt',
#  u'annotations',
#  u'tweepy',
#  u'matlab',
#  u'sklearn-pandas',
#  u'deque',
#  u'vk',
#  u'xlwt',
#  u'pylint',
#  u'yahoo',
#  u'pdfpages',
#  u'datareader',
#  u'subclass',
#  u'oop',
#  u'bounding-box',
#  u'unpack',
#  u'document',
#  u'sample',
#  u'lowercase',
#  u'salesforce',
#  u'join',
#  u'ibm',
#  u'hour',
#  u'large-files',
#  u'mean-shift',
#  u'for-loop',
#  u'save',
#  u'fuzzy-comparison',
#  u'self-join',
#  u'reduction',
#  u'compiler-optimization',
#  u'printing',
#  u'del',
#  u'install',
#  u'foreign-keys',
#  u'chinese-locale',
#  u'pickle',
#  u'spyder',
#  u'dayofweek',
#  u'social-networking',
#  u'sqlite',
#  u'figure',
#  u'excel-formula',
#  u'process',
#  u'column-width',
#  u'file-descriptor',
#  u'inner-join',
#  u'substring',
#  u'currency',
#  u'numbers',
#  u'spreadsheet-excel-writer',
#  u'panel-data',
#  u'heroku',
#  u'currency-exchange-rates',
#  u'axis',
#  u'normalize',
#  u'graphlab',
#  u'gcc',
#  u'lxml',
#  u'datetimeindex',
#  u'columnname',
#  u'shapefile',
#  u'nvd3.js',
#  u'keras',
#  u'range',
#  u'pyqt',
#  u'leading-zero',
#  u'string-concatenation',
#  u'sapply',
#  u'stemming',
#  u'attachment',
#  u'machine-learning',
#  u'separator',
#  u'matplotlib-basemap',
#  u'csv',
#  u'css',
#  u'stock',
#  u'distinct-values',
#  u'multi-level',
#  u'quoting',
#  u'timedelta',
#  u'excel-2011',
#  u'max',
#  u'excel-2013',
#  u'lag',
#  u'mapping',
#  u'embed',
#  u'nearest-neighbor',
#  u'intellij-idea',
#  u'astropy',
#  u'string-formatting',
#  u'yelp',
#  u'records',
#  u'overpass-api',
#  u'date',
#  u'summarize',
#  u'out-of-memory',
#  u'types',
#  u'variable-length',
#  u'summarization',
#  u'argparse',
#  u'runtime',
#  u'export-to-csv',
#  u'footer',
#  u'k-means',
#  u'command-line-interface',
#  u'counter',
#  u'lines',
#  u'try-except',
#  u'code-statistics',
#  u'django',
#  u'atan2',
#  u'extrapolation',
#  u'language-lawyer',
#  u'lookup-tables',
#  u'group-by',
#  u'element',
#  u'nltk',
#  u'bins',
#  u'couchdb',
#  u'anti-join',
#  u'delimited',
#  u'startswith',
#  u'hierarchy',
#  u'functools',
#  u'fft',
#  u'string-length',
#  u'pie-chart',
#  u'combinations',
#  u'comma',
#  u'iso-8859-1',
#  u'qlineedit',
#  u'hbase',
#  u'cumsum',
#  u'digest',
#  u'rebasing',
#  u'p-value',
#  u'group',
#  u'uuid',
#  u'multiple-files',
#  u'psycopg2',
#  u'text-parsing',
#  u'sqldf',
#  u'selenium',
#  u'epoch',
#  u'coordinates',
#  u'jit',
#  u'permanent',
#  u'degrees',
#  u'minute',
#  u'find-occurrences',
#  u'highstock',
#  u'isnullorempty',
#  u'multithreading',
#  u'statistics-bootstrap',
#  u'setting',
#  u'data-type-conversion',
#  u'arguments',
#  u'orange',
#  u'doctest',
#  u'return',
#  u'chaining',
#  u'error-handling',
#  u'pyenchant',
#  u'python',
#  u'timestamp',
#  u'memory-management',
#  u'indexing',
#  u'continuous-integration',
#  u'floating',
#  u'scaling',
#  u'python-xarray',
#  u'ms-word',
#  u'scipy',
#  u'jinja2',
#  u'subtraction',
#  u'datetime64',
#  u'interrupt',
#  u'dataset',
#  u'animation',
#  u'decorator',
#  u'qt',
#  u'linear-programming',
#  u'xlm',
#  u'cloudera',
#  u'equality',
#  u'left-join',
#  u'relativedelta',
#  u'decimal',
#  u'gitlab',
#  u'events',
#  u'explode',
#  u'merge',
#  u'subquery',
#  u'logistic-regression',
#  u'nfs',
#  u'confusion-matrix',
#  u'arrow',
#  u'date-format',
#  u'h5py',
#  u'pycharm',
#  u'feature-selection',
#  u'memsql',
#  u'attributeerror',
#  u'mean',
#  u'subset',
#  u'matplotlib-venn',
#  u'pdflatex',
#  u'suppress-warnings',
#  u'stored-procedures',
#  u'eclipse',
#  u'tolist',
#  u'rowdeleting',
#  u'series',
#  u'reduce',
#  u'google-adwords',
#  u'numeric',
#  u'upload',
#  u'fractions',
#  u'frequency',
#  u'static',
#  u'c++',
#  u'namedtuple',
#  u'floating-accuracy',
#  u'loops',
#  u'word2vec',
#  u'xlrd',
#  u'extract',
#  u'category',
#  u'ftp',
#  u'reportlab',
#  u'dbscan',
#  u'tableau',
#  u'matrix',
#  u'command-line',
#  u'mandrill',
#  u'rounding',
#  u'dynamic-columns',
#  u'python-nvd3',
#  u'data-dictionary',
#  u'astronomy',
#  u'blank-line',
#  u'elastic-beanstalk',
#  u'com',
#  u'chunking',
#  u'formula',
#  u'get',
#  u'greatest-n-per-group',
#  u'math',
#  u'processing-efficiency',
#  u'cosine-similarity',
#  u'dictionary',
#  u'maping',
#  u'amazon-web-services',
#  u'text-mining',
#  u'args',
#  u'diagonal',
#  u'csvkit',
#  u'rows',
#  u'perceptron',
#  u'typeconverter',
#  u'kruskal-wallis',
#  u'gis',
#  u'byte',
#  u'bash',
#  u'user-input',
#  u'raster',
#  u'median-of-medians',
#  u'pandasql',
#  u'data-representation',
#  u'deprecated',
#  u'computational-finance',
#  u'traceback',
#  u'non-linear-regression',
#  u'days',
#  u'date-parsing',
#  u'filter',
#  u'django-models',
#  u'elasticsearch',
#  u'import-from-excel',
#  u'multi-index',
#  u'styles',
#  u'assign',
#  u'lambda',
#  u'binaryfiles',
#  u'suffix',
#  u'probability',
#  u'encoding',
#  u'variables',
#  u'bioinformatics',
#  u'pandas-datareader',
#  u'rank',
#  u'nested',
#  u'boto3',
#  u'multiplication',
#  u'multiplying',
#  u'technical-indicator',
#  u'enumerate',
#  u'large-data',
#  u'neo4j',
#  u'non-ascii-characters',
#  u'apache-spark',
#  u'pydev',
#  u'uniqueidentifier',
#  u'monthcalendar',
#  u'cassandra',
#  u'pyinstaller',
#  u'missing-data',
#  u'flask-sqlalchemy',
#  u'sublimetext2',
#  u'offset',
#  u'google-cloud-datalab',
#  u'bokeh',
#  u'normalization',
#  u'windows-10',
#  u'cpu-speed',
#  u'percentage',
#  u'hdf5storage',
#  u'stacked-chart',
#  u'gps',
#  u'subplot',
#  u'testing',
#  u'asymmetric',
#  u'quandl',
#  u'xlsxwriter',
#  u'pyqt4',
#  u'broadcast',
#  u'github',
#  u'while-loop',
#  u'fuzzy',
#  u'copy',
#  u'scientific-notation',
#  u'entropy',
#  u'jquery',
#  u'distance',
#  u'grep',
#  u'slack',
#  u'opencsv',
#  u'model-fitting',
#  u'pyalgotrade',
#  u'pointers',
#  u'mariadb',
#  u'iteration',
#  u'imputation',
#  u'split-apply-combine',
#  u'r',
#  u'chardet',
#  u'plotly',
#  u'filehandler',
#  u'amazon-s3',
#  u'dot-product',
#  u'data-processing',
#  u'interactive',
#  u'debugging',
#  u'google-bigquery',
#  u'bs4',
#  u'anaconda',
#  u'formatting',
#  u'python-datetime',
#  u'yahoo-finance',
#  u'dask',
#  u'columnheader',
#  u'information-theory',
#  u'scatter-plot',
#  u'dedupeplugin',
#  u'mechanize',
#  u'null',
#  u'any',
#  u'facebook-graph-api',
#  u'character-encoding',
#  u'pyspark-sql',
#  u'angle',
#  u'py2exe',
#  u'min',
#  u'storage',
#  u'pspice',
#  u'pdf',
#  u'python-2.5',
#  u'eof',
#  u'weather-api',
#  u'instance',
#  u'internal',
#  u'python.net',
#  u'sframe',
#  u'performance',
#  u'pyephem',
#  u'boxplot',
#  u'visual-studio',
#  u'folders',
#  u'formulas',
#  u'populate',
#  u'artificial-intelligence',
#  u'buffer',
#  u'glob',
#  u'correlation',
#  u'python-decorators',
#  u'crash',
#  u'netezza',
#  u'beta',
#  u'awk',
#  u'tkinter',
#  u'mysql-connector-python',
#  u'pair',
#  u'python-3.5.2',
#  u'class',
#  u'latex',
#  u'exe',
#  u'jupyter',
#  u'crosstab',
#  u'word-cloud',
#  u'mathematical-optimization',
#  u'windows',
#  u'random-sample',
#  u'average',
#  u'nan',
#  u'order',
#  u'logical-operators',
#  u'h2o',
#  u'wildcard',
#  u'diagnostics',
#  u'categorization',
#  u'dummy-variable',
#  u'deprecation-warning',
#  u'method-chaining',
#  u'threadpoolexecutor',
#  u'nlp',
#  u'cdf',
#  u'py4j',
#  u'brute-force',
#  u'text',
#  u'immutability',
#  u'random',
#  u'html-parsing',
#  u'lda',
#  u'datetime',
#  u'cross-validation',
#  u'theano',
#  u'colors',
#  u'miniconda',
#  u'networkx',
#  u'environ',
#  u'apache-pig',
#  u'find',
#  u'xml',
#  u'cell',
#  u'linear-algebra',
#  u'upgrade',
#  u'ensembles',
#  u'parameters',
#  u'title',
#  u'hdfs',
#  u'32bit-64bit',
#  u'cextension',
#  u'sqlplus',
#  u'pyhdf',
#  u'override',
#  u'setup.py',
#  u'arcgis',
#  u'local',
#  u'ranking',
#  u'stata',
#  u'notation',
#  u'pyspark',
#  u'df',
#  u'numpy-memmap',
#  u'pass-by-reference',
#  u'data-cleansing',
#  u'zipfile',
#  u'partitioning',
#  u'fuzzy-search',
#  u'subclassing',
#  u'interprocess',
#  u'datasource',
#  u'synchronization',
#  u'apache-spark-sql',
#  u'neural-network',
#  u'report',
#  u'graphviz',
#  u'geo',
#  u'gensim',
#  u'wunderground',
#  u'xml-parsing',
#  u'design-patterns',
#  u'google-drive-sdk',
#  u'pearson',
#  u'python-multiprocessing',
#  u'pydot',
#  u'redis',
#  u'median',
#  u'google-maps',
#  u'python-requests',
#  u'summary',
#  u'facet-grid',
#  u'unique-id',
#  u'datetime-format',
#  u'contain',
#  u'hpc',
#  u'random-forest',
#  u'vincent',
#  u'3d',
#  u'where',
#  u'to-json',
#  u'shell',
#  u'set',
#  u'cassandra-2.0',
#  u'reference',
#  u'google-cloud-storage',
#  u'argmax',
#  u'frame',
#  u'google-geocoder',
#  u'cx-freeze',
#  u'module',
#  u'analytics',
#  u'sed',
#  u'user-interface',
#  u'calendar',
#  u'iqr',
#  u'timezoneoffset',
#  u'ipywidgets',
#  u'constraints',
#  u'sequences',
#  u'timeit',
#  u'bilinear-interpolation',
#  u'mongodb-query',
#  u'forecasting',
#  u'html5',
#  u'ta-lib',
#  u'label',
#  u'libraries',
#  u'nested-lists',
#  u'locality-sensitive-hash',
#  u'q-lang',
#  u'outliers',
#  u'cluster-computing',
#  u'network-programming',
#  u'data.table',
#  u'import',
#  u'ms-access',
#  u'email',
#  u'lapply',
#  u'tableheader',
#  u'data-import',
#  u'mplot3d',
#  u'profiling',
#  u'resampling',
#  u'identifier',
#  u'xslt',
#  u'buckets',
#  u'javascript',
#  u'transpose',
#  u'azure-ml',
#  u'scalability',
#  u'pypi',
#  u'google-api-python-client',
#  u'conda',
#  u'posixlt',
#  u'key',
#  u'ipython',
#  u'python-ggplot',
#  u'linear-interpolation',
#  u'packages',
#  u'distribution',
#  u'parentheses',
#  u'installation',
#  u'reverse',
#  u'eigenvalue',
#  u'primary-key',
#  u'tf-idf',
#  u'tidyr',
#  u'facet',
#  u'if-statement',
#  u'itertools',
#  u'case-insensitive',
#  u'maxlength',
#  u'expand',
#  u'attributes',
#  u'canopy',
#  u'minhash',
#  u'blaze',
#  u'strftime',
#  u'preprocessor',
#  u'file-io',
#  u'geolocation',
#  u'multiple-columns',
#  u'filtering',
#  u'data-science',
#  u'duplicity',
#  u'datediff',
#  u'period',
#  u'dataframe',
#  u'sampling',
#  u'pymssql',
#  u'serialization',
#  u'iterable-unpacking',
#  u'diff',
#  u'word-frequency',
#  u'iterable',
#  u'logic',
#  u'list-comprehension',
#  u'latitude-longitude',
#  u'java',
#  u'accelerometer',
#  u'union',
#  u'encryption',
#  u'nosql',
#  u'quantile',
#  u'charts',
#  u'vscode',
#  u'json',
#  u'special-characters',
#  u'pyexcelerate',
#  u'tensorflow',
#  u'feather',
#  u'in-place',
#  u'numpy',
#  u'aggregate-functions',
#  u'xlsx',
#  u'ram',
#  u'rhdf5',
#  u'sumifs',
#  u'counting',
#  u'exact-match',
#  u'covariance',
#  u'binning',
#  u'reverse-geocoding',
#  u'multidimensional-array',
#  u'tweets',
#  u'qtableview',
#  u'pytz',
#  u'financial',
#  u'line-plot',
#  u'string-matching',
#  u'variable-assignment',
#  u'ironpython',
#  u'utf-16',
#  u'quantitative-finance',
#  u'postgis',
#  u'hasattr',
#  u'glm',
#  u'floating-point',
#  u'exception',
#  u'pca',
#  u'exponential',
#  u'grid-search',
#  u'rolling-sum',
#  u'value',
#  u'colorbar',
#  u'hdf',
#  u'optimization',
#  u'multivalue',
#  u'momentum',
#  u'setuptools',
#  u'scatter',
#  u'statsmodels',
#  u'unpivot',
#  u'ipython-notebook',
#  u'moving-average',
#  u'rename',
#  u'mysql-python',
#  u'xgboost',
#  u'digital-ocean',
#  u'angularjs',
#  u'binary-matrix',
#  u'stdout',
#  u'data-structures',
#  u'ip',
#  u'axis-labels',
#  u'dictvectorizer',
#  u'subprocess',
#  u'concatenation',
#  u'sas',
#  u'numba',
#  u'ansible',
#  u'notnull',
#  u'io',
#  u'azimuth',
#  u'pypyodbc',
#  u'comments',
#  u'timeserieschart',
#  u'regression',
#  u'finance',
#  u'binary',
#  u'whois',
#  u'pooling',
#  u'iopro',
#  u'reshape',
#  u'multivariate-testing',
#  u'kdtree',
#  u'locking',
#  u'hadoop',
#  u'enumeration',
#  u'amazon-redshift',
#  u'google-visualization',
#  u'html',
#  u'split',
#  u'sqlite3',
#  u'survey',
#  u'android',
#  u'concurrent.futures',
#  u'pass-by-value',
#  u'interpolation',
#  u'ordinal',
#  u'graph-theory',
#  u'google-spreadsheet',
#  u'data-modeling',
#  u'hadoop-streaming',
#  u'views',
#  u'closest',
#  u'vectorization',
#  u'numerical',
#  u'atom-editor',
#  u'filenames',
#  u'arcmap',
#  u'bloomberg',
#  u'census',
#  u'aggregate',
#  u'stack',
#  u'mosaic',
#  u'knn',
#  u'coding-style',
#  u'partition',
#  u'undefined',
#  u'data-mining',
#  u'database',
#  u'geopandas',
#  u'quartile',
#  u'dashdb',
#  u'difflib',
#  u'analysis',
#  u'highcharts',
#  u'urlparse',
#  u'pep8',
#  u'many-to-many',
#  u'flags',
#  u'azure-machine-learning',
#  u'gzip',
#  u'position',
#  u'docker',
#  u'parallel-processing',
#  u'sql-server',
#  u'cortana-intelligence',
#  u'valueconverter',
#  u'doc2vec',
#  u'clob',
#  u'selenium-webdriver',
#  u'zipline',
#  u'python-2.7',
#  u'data-munging',
#  u'rest',
#  u'python-2.6',
#  u'data-visualization',
#  u'intervals',
#  u'decision-tree',
#  u'unicode',
#  u'mysql',
#  u'd3py',
#  u'matrix-multiplication',
#  u'alignment',
#  u'projection',
#  u'csv-import',
#  u'visualization',
#  u'ordereddictionary',
#  u'intersection',
#  u'boolean-expression',
#  u'pyelasticsearch',
#  u'azure-storage-blobs',
#  u'character',
#  u'exception-handling',
#  u'd3.js',
#  u'signals',
#  u'opencv',
#  u'add',
#  u'tuples',
#  u'msgpack',
#  u'python-unittest',
#  u'input',
#  u'lmdb',
#  u'osgeo',
#  u'transformation',
#  u'match',
#  u'igraph',
#  u'bin',
#  u'ibm-bluemix',
#  u'jython',
#  u'hover',
#  u'casting',
#  u'openpyxl',
#  u'format',
#  u'stack-overflow',
#  u'python-multithreading',
#  u'aggregation',
#  u'nginx',
#  u'is-empty',
#  u'sentiment-analysis',
#  u'dokku',
#  u'libs',
#  u'integer',
#  u'syntax',
#  u'unique',
#  u'double-quotes',
#  u'linux',
#  u'insert',
#  u'sorting',
#  u'header',
#  u'scikit-learn',
#  u'geospatial',
#  u'server',
#  u'api',
#  u'import-from-csv',
#  u'least-squares',
#  u'quantreg',
#  u'kde',
#  u'time-series',
#  u'output',
#  u'memory-leaks',
#  u'rstudio',
#  u'odo',
#  u'grouping',
#  u'algorithmic-trading',
#  u'fonts',
#  u'methods',
#  u'centos',
#  u'sequence',
#  u'outer-join',
#  u'uppercase',
#  u'twitter',
#  u'conditional',
#  ...}

# %%
def number_of_answers(data):
    
    num_answers = {}
    
    for i in range(len(data)):
        num_answers[data[i]['title']]=data[i]['answer_count']
        
    return num_answers

# %%
num_of_answers = number_of_answers(data_question_tag)

# %%
num_of_answers
# Out:
# {u'Pandas Grouping - Values as Percent of Grouped Totals Based on Another Column': 1,
#  u'pandas.HDFStore.append_to_multiple with pandas.MultiIndex': 0,
#  u'How to label columns by reading in from a file in pandas': 1,
#  u'Pandas TimeGrouper issue - Typeerror on &quot;time&quot; index': 1,
#  u'python pandas Ignore Nan in integer comparisons': 1,
#  u'How to create a column depending on the row index values in a multiindex pandas dataframe?': 2,
#  u'Pandas Dataframe Transpose': 1,
#  u'Can&#39;t execute Python Pandas set_value': 2,
#  u'Pandas complex processing with groupby': 2,
#  u'Python backtest using percentage based commission': 1,
#  u'Create a 2D plot pixel grid based on a pandas series of lists': 2,
#  u'How to calculate the mean of a pandas DataFrame with NaN values': 1,
#  u'ValueError when plotting array of values against dates numpy': 1,
#  u'using Python, How to group a column in Dataframe by the hour?': 3,
#  u'Dataframe with column of ranges. Given number, select row where number occurs': 2,
#  u'store complex dictionary in pandas dataframe': 1,
#  u'How to create dictionary of dictionaries from a dataframe using python&#39;s pandas': 1,
#  u'Adding rows to Pandas dataframe': 3,
#  u'Replace two rows in a Pandas DataFrame with five rows?': 0,
#  u'Update a null values in countryside column in a data frame with reference to valid countrycode column from another data frame using python': 1,
#  u'merging large data sets using Pandas': 1,
#  u'Using pd.apply() with shift to compare adjacent rows': 2,
#  u'Pandas: Parsing / converting a column as date after importing from read_sql': 2,
#  u'Adding a new column to the table in a database using sqlalchemy, pyodbc': 1,
#  u'Pandas - group by consecutive ranges': 2,
#  u'Removing duplicates indices from multi-index dataframe': 0,
#  u'python pandas HDF5Store append new dataframe with long string columns fails': 1,
#  u'Printing resampled data into a text or csv file': 1,
#  u'List index out of range with Panda read_csv': 0,
#  u'Pandas: get some data from dataframe': 1,
#  u'Join dataframes by column values pandas': 1,
#  u'Pandas: Subset Data Where Multiple Row Values Are Not All The Same': 1,
#  u'python pandas: date/time function to compute time period': 2,
#  u'How to call value from excel on python': 1,
#  u'creating an sql query using a DataFrame column': 1,
#  u'What is the equivalent for Iterrows in Python 3.5': 0,
#  u'Pandas : Making Decision on groupby size()': 2,
#  u'How to get mean of rows selected with another column&#39;s values in pandas': 3,
#  u'Given multiple two columns sets of a min/max how to return index if a number falls between min/max': 2,
#  u'How to count rows in a data frame in Pandas conditionally against values in another column of the same data frame?': 3,
#  u'sorting records with in grouped item in a dataframe': 1,
#  u'create multiple columns from 1 column pandas': 2,
#  u'Parse User name for extracting user location Twitter': 1,
#  u'averaging every five minutes data as one datapoint in pandas dataframe ovewr multiple days': 1,
#  u'How to save split data in panda in reverse order?': 2,
#  u'pandas insert dataframe into database': 1,
#  u'.gt operator in Pandas DataFrame': 1,
#  u'How to conditionally transpose in pandas (similar to SQL case when withn group by)': 2,
#  u'Sort tenors in finance notation': 4,
#  u'Merge Dataframe by regular expression or fuzzy match': 1,
#  u'pandas tricky intra-column logic': 2,
#  u'How to fill an array &quot;column&quot; with calculated numbers': 6,
#  u'Python Pandas Data sampling/aggregation': 2,
#  u'Applying function to Pandas dataframe by column': 2,
#  u'How to delete columns with at least 20% missing values': 2,
#  u'group by on scipy sparse matrix': 1,
#  u'Python pandas .loc multiple conditions and modify part of date': 1,
#  u'python - different encoding results by setting the &quot;encoding&quot; parameter in diff. functions': 1,
#  u'Transposing selectively in pandas (python 2.7)': 1,
#  u'How to get distinct count of keys along with other aggregations in pandas': 1,
#  u'Grouping, calculating, and sorting scoring data': 1,
#  u'Reshaping a pandas dataframe': 2,
#  u'SQLite3 with Python and Pandas slows down when adding lots of data': 1,
#  u'How to create hierarchical columns in pandas?': 2,
#  u'python pandas dataframe - can&#39;t figure out how to lookup an index given a value from a df': 1,
#  u'pandas: append new column of row subtotals': 2,
#  u'Boolean indexing a DataFrame in pandas an replacing the columns with elements of a Series where condition is True': 1,
#  u'counter for many distinct values in data frame column': 1,
#  u'how does python operator overloading works': 1,
#  u'Any way to create a column of tuples from a column of floats in pandas?': 2,
#  u'replace df index values with values from a list but ignore empty strings': 1,
#  u'replace column in data frame with elements from another column - python': 1,
#  u'Python equivalent of SQL: SELECT w/ MAX() and GROUP BY': 1,
#  u'Pandas tuples groupby aggregation': 1,
#  u'Unable to install pandas in python 3.5.1 in command prompt': 0,
#  u'Pandas - column not found in dataframe': 2,
#  u'pandas histogram with logarithmic axes': 2,
#  u'Delete row in column when value in column is a string': 1,
#  u'Subset rows by partially matching two columns for words greater than n characters': 1,
#  u'Inconsistent results when concatenating parsed csv files': 2,
#  u'Pandas sorting multindex and reset': 1,
#  u'Python Pandas memory - subsetting and releasing main data frame': 1,
#  u'pandas: drop indices in dataframe A which don&#39;t appear in dataframe B': 1,
#  u'Filtering negative timedeltas': 1,
#  u'Minor ticks for plot using Pandas': 1,
#  u'Pandas+Python - How to know when a value changes?': 2,
#  u'Concating a nested numpy array into 2D array': 1,
#  u'Speeding up cross-reference filtering in Pandas DB': 2,
#  u'Backtesting Long/Short Market Neutral Z-Score Strategy with Custom Factors and Custom Stock Universe': 0,
#  u'Not True, Python similar to R': 1,
#  u'How does Python Pandas process a list of tables?': 2,
#  u'How to convert Spark RDD to pandas dataframe in ipython?': 2,
#  u'HTML IDs for rows of a Pandas Dataframe.to_html() output': 1,
#  u'Comparing two DataFrames by one column with a return of three different outputs with Panadas': 1,
#  u'How can I rename multiple columns with numbers in python?': 2,
#  u'Using slices in Python': 1,
#  u'Python (pandas) fast mapping of multiple datetimes to their series indices?': 3,
#  u'JSON data to Pandas DataFrame': 2,
#  u'parallel processing with dataframes python': 0,
#  u'Calculate z-score in data bunch but excluding N.A': 1,
#  u'KeyError while using UnbalancedDataset package to over-sample a dataset (in pandas.index.IndexEngine.get_loc)': 1,
#  u'Pandas: How to convert dict of dict into a dataframe': 0,
#  u'Read a column then write in another column from a CSV file with Python': 1,
#  u'Access Shared DataFrame in Multiprocessing Map': 1,
#  u'pandas timeseries DF slice and selection': 2,
#  u'Counting Mulitple Values in a Python pandas Dataframe Column': 1,
#  u'Python Pandas is it possible to find the max value in a generated series without having to store the series into memory?': 3,
#  u'Merging csv files using python and pandas (overlapping rows)': 2,
#  u'provide a mask to pandas dataframe as function argument': 1,
#  u'Python pandas - apply function to grouped dataframe': 1,
#  u'Behavior of Pandas DataFrame .ix method': 1,
#  u'A fast method for comparing a value in one Panda\u2019s row to another in a previous row?': 2,
#  u'How to select lines from a pandas dataset based on a regex?': 1,
#  u'Coordinates from UTM to Latitude and Longitude in pandas': 1,
#  u'Pandas reading from csv file and filling missing values for datetime index': 1,
#  u'Different sequence of names with pandas': 2,
#  u'Need warning message if count of each country code is less than 5': 3,
#  u'How to drop the rows from dataframe that has all column values as boolean false': 2,
#  u'Alternative to sum or prod for subtraction or division in pandas series': 2,
#  u'Pandas: summing unique values in dataframe cells': 0,
#  u'Python NVD3 from Pandas dataframe': 0,
#  u'Pandas number of unique users grouped by year-week': 2,
#  u'pandas memory error after a certain skiprows parameter': 2,
#  u'viewing nested JSON data into a pandas dataframe': 1,
#  u'Python pandas resampling instantaneous hourly data to daily timestep including 00:00 of next day': 1,
#  u'In pandas, set a new column and update existing column': 1,
#  u'Selecting duplicate rows in pandas': 1,
#  u'Floating accuracy in pandas': 0,
#  u'DataFrame of means of top N most correlated columns': 2,
#  u'How to replace all non-NaN entries of a dataframe with 1 and all NaN with 0': 6,
#  u'How to do time diff in each group on Pandas in Python': 1,
#  u'Nested loops with Pandas using too much memory': 1,
#  u'Pandas, position of iloc in df': 1,
#  u'Column order in pandas.concat': 2,
#  u'how to vectorise Pandas calculation that is based on last x rows of data': 1,
#  u'Convert Array of DataFrames to Single DataFrame': 2,
#  u'Transposing a subset of columns in a Pandas DataFrame while using others as grouping variable?': 2,
#  u'How to multiply each row in pandas dataframe by a different value': 1,
#  u'Writing special ch&#228;racters with pyExcelerate? How to keep utf-8 encoding?': 1,
#  u'How can i split a pandas dataframe in such a way that for each split value it creates a column': 1,
#  u'How to search datetime index and place None-values to another variables whenever it is weekend Python': 1,
#  u'How to turn pandas data frame w/ row per unique term &amp; date into df which contains 1 row per date, w/ unique terms + their values as columns?': 1,
#  u'how to copy and paste sql query in pandas read_Sql': 1,
#  u'pandas read_table parse_dates: New date column already in dict of another column?': 0,
#  u'Python pandas transpose data issue': 1,
#  u'python pandas conditional sum on dataframe which is grouped on multiple columns': 1,
#  u'Convert a pandas data frame to a pandas data frame with another style': 1,
#  u'Unexpected behaviour when grouping outliers in pandas [Python]': 1,
#  u'pandas - percentage of matr': 1,
#  u'&quot;ValueError: unknown locale: UTF-8&quot; when importing pandas in python 2.7': 1,
#  u'join/search/sum in Pandas Python': 3,
#  u'Pandas: take whichever column is not NaN': 5,
#  u'Changing self.variables inside __exit__ method of Context Managers': 0,
#  u'time in strings format: python': 2,
#  u'How to combine the rows in data frame?': 1,
#  u'How Can I Detect Gaps and Consecutive Periods In A Time Series In Pandas': 1,
#  u'Using groupby group names in function': 2,
#  u'How to compute jaccard similarity from a pandas dataframe': 1,
#  u'Is there a way to get an r-squared value for nonlinear regression?': 0,
#  u'Quick way to find the duplicate cell in a certain column of data frame in python-pandas?': 1,
#  u'How to change values of a dataframe through groupby in pandas': 1,
#  u'Pandas Panels to HDF5 and import into R': 0,
#  u'Selecting a specific column from sqllite database returns column name when passed in qmark format in Python': 0,
#  u'loss of precision when using pandas to read excel': 2,
#  u'Aggregation over Partition - pandas Dataframe': 1,
#  u'Renaming columns in csv by column index': 2,
#  u'factorize columns of a pandas data frame': 1,
#  u'Creating class object from pandas series and applying methods': 2,
#  u'Pandas indexer methods and tuples as parameters': 2,
#  u'How to print like jupyter notebook&#39;s default cell output': 1,
#  u'Plot dataframe grouped by one column, and hue by another column': 2,
#  u'AttributeError: &#39;NoneType&#39; object has no attribute &#39;lstrip&#39;': 3,
#  u'Compute t-test for two tables with N/A': 1,
#  u'pandas: problems with merging dataframes': 1,
#  u'HDF5: Is there a way to rename the column names in an existing HDF5 table?': 1,
#  u'Cleanest way to filter a Pandas dataframe?': 3,
#  u'install ta-lib in windows 10 under Anaconda': 0,
#  u'Groupby with TimeGrouper &#39;backwards&#39;': 2,
#  u'How can I make a python candlestick chart clickable in matplotlib': 1,
#  u'How to filter rows that fall within 1st and 3rd quartile of a particular column in pandas dataframe?': 3,
#  u'pandas: write tab-separated dataframe with literal tabs with no quotes': 1,
#  u'Opening and closing files in a loop': 3,
#  u'In pandas how to filter based on a particular weekday and range of time': 1,
#  u'Overflow error in Python with pandas': 1,
#  u'Python - How to Compare a column value of one row with value in next row': 1,
#  u'Re-index data frame; fill index using elements from multiple columns': 1,
#  u'Align numeric indexes to temporal period in pandas': 1,
#  u'CParserError: Error tokenizing data': 2,
#  u'Python: Easier way to merge several columns of an array into one': 2,
#  u'Sort pandas DataFrame with function over column values': 3,
#  u'Find pre/post-decessor in pandas for each group': 0,
#  u'Python Pandas: Creating seasonal DateOffset object?': 1,
#  u'Calculate difference between first valid value and last valid value in DataFrame per row?': 2,
#  u'y-axis scaling in seaborn vs pandas': 2,
#  u'How to tokenize unicode text with nltk?': 1,
#  u'python pandas dataframe: naming columns is making new columns': 2,
#  u'How to &quot;merge&quot; multiple pandas dataframes with the index as dataframe column?': 1,
#  u'Can someone explain what does the map function do?': 2,
#  u'Pandas read_csv: Ignore second header line': 2,
#  u'mapping dataframes not series pandas': 2,
#  u'In Pandas, how do I create groups by using a function?': 3,
#  u'Maximum value change after filter criteria met': 0,
#  u'convert pandas dataframe to list of tuples and drop all pandas datatypes': 1,
#  u'Python: (Seaborn?) heat map from irregular meshgrid': 0,
#  u'how to optimize the following code?': 1,
#  u'Adding missing dates to dataframe using reindex replaces data': 1,
#  u'Set Union in pandas': 2,
#  u'Iterating pandas dataframe, checking values and creating some of them': 2,
#  u'Pandas - applying groupings and counts to multiple columns in order to generate/change a dataframe': 2,
#  u'How to concatenate pandas.DataFrames columns': 2,
#  u'Cant Call Column': 1,
#  u'pandas.io.common.CParserError: Error tokenizing data. C error: out of memory': 0,
#  u'How to sample a numpy array and perform computation on each sample efficiently?': 1,
#  u'Math Eval String in DataFrame Python': 1,
#  u'Pandas: How to change the structure of a DataFrame by inserting rows with blank values': 3,
#  u'Conditionally update Data Frame column': 2,
#  u'I want to drop_duplicates from TextFileReader and save what remains into separate files': 1,
#  u'Pandas: Subtracting two date columns and the result being an integer': 2,
#  u'Pandas: condition to string': 1,
#  u'Pandas: keeping only first row of data in each 60 second bin': 2,
#  u'exponential moving average value error: mutual exclusivity': 0,
#  u'How to replace values in a column if another column is a NaN?': 1,
#  u'Find integer row-index from pandas index': 3,
#  u'Python Error: Found array with 0 sample(s) (shape=(0, 262)) while a minimum of 1 is required': 0,
#  u'pandas new column equals another column with condition': 1,
#  u'How can I disable the label when plotting pandas data?': 2,
#  u'convert dataframe column of type &#39;object&#39; into type list': 1,
#  u'Why there is a difference between 32 bit and 64 bit numpy/pandas': 1,
#  u'How should I go about geolocating 1,100,000 lines of coordinate information?': 3,
#  u'how to create dummies for certain columns by pandas get_dummies() method?': 2,
#  u'Python pandas count number of Regex matches in a string': 2,
#  u'Python Writing lists to csv': 4,
#  u'Python Groupby omitting columns': 1,
#  u'Using Difflib to combine Excel sheets': 1,
#  u'Assignment through chained indexers': 1,
#  u'de-duplicate timeindex by adding milliseconds': 1,
#  u'Python: String slice in pandas DataFrame is a series? I need it to be convertible to int': 1,
#  u'Pandas: DataFrame groupby for year/month and return with new DatetimeIndex': 2,
#  u'Change values in pandas dataframe according to value_counts()': 2,
#  u'Python pandas:Fast way to create a unique identifier for groups': 1,
#  u'Pandas pd.DataFrame converts to Tuples instead of Dataframe': 1,
#  u'Convert Panda DataFrame to Panel-like structure': 1,
#  u'Pandas read_sql_query converting integer column to float': 1,
#  u'Appending Pandas dataframes in for loop results in ValueError': 1,
#  u'Pandas Pivot table - incremental column names': 2,
#  u'can a pandas.Period represent an arbitrary time span?': 1,
#  u'Pandas apply function to unique values in column': 1,
#  u'Delete column(s) from very large CSV file using pandas or blaze': 3,
#  u'How to identify row and column based on top-K values in Pandas data frame': 4,
#  u'Convert a dict to a pandas DataFrame': 2,
#  u'extract column value based on another column pandas dataframe': 3,
#  u'Reindexing a multiindex in pandas dataframe': 1,
#  u'Value counts for all combinations of groups': 1,
#  u'Cannot compare type &#39;Timestamp&#39; with type &#39;int&#39;': 2,
#  u'pandas: complex filter through groupby': 1,
#  u'Calculate z_score for a column grouped by another column': 1,
#  u'Convert Pandas tseries object to a DataFrame': 1,
#  u'Using Python 3 to consolidated information from various excel files (same format) into a specific output format': 1,
#  u'Python: Getting Error: Too many values to unpack (expected 2) while looping through columns of Dataframe': 1,
#  u'Conditional fill dataframe pandas': 1,
#  u'Using chunksize to select data but keeping the same order?': 1,
#  u'Seaborn plots kdeplot but not distplot': 1,
#  u'Horizontal Bar Chart on Pandas Data Frame with Dynamic Column Names': 2,
#  u'Pandas: Compress Column Names to Cell Values where True': 1,
#  u'How to retrieve an index from an object with one element only in pandas?': 0,
#  u'Data From Excel Using Python': 0,
#  u'Assign value to cell in pandas dataframe': 1,
#  u'How to count the number of group elements with pandas': 1,
#  u'converting sparse dataframe to dense dataframe': 2,
#  u'Sklearn GridSearchCV using Pandas DataFrame Column': 1,
#  u'Pandas autocorrelation plot not showing from Spyder console': 0,
#  u'Pandas: reorganizing a dataframe': 2,
#  u'Flatten/ravel/collapse 3-dimensional xr.DataArray (Xarray) into 2 dimensions along an axis?': 1,
#  u'How to cluster a time series using KMeans in python': 0,
#  u'Seaborn countplot orient not working': 0,
#  u'Pandas + HDF5 Panel data storage for large data': 1,
#  u'How can I pass a pandas dataframe as an arg and manipulate it?': 2,
#  u'Pandas read_csv() works on CSV file in Python 3 but returns NaNs in Python 2': 1,
#  u'Changing an exact value in csv using Pandas': 1,
#  u'How to drop duplicate from DataFrame taking into account value of another column': 1,
#  u'AttributeError: &#39;numpy.ndarray&#39; object has no attribute &#39;columns&#39;': 1,
#  u'python pandas from 0/1 dataframe to an itemset list': 3,
#  u'pandas appending df1 to df2 get 0s/NaNs in result': 2,
#  u'Python Pandas: Convert Minutes to Datetime': 1,
#  u'How do you map a Series to a dictionary?': 1,
#  u'pandas dataframe string formatting (access a given column)': 2,
#  u'regex match space forward slash and space &#39; / &#39;': 2,
#  u'sklearn stratified sampling based on a column': 2,
#  u'Delete strings from file using python': 2,
#  u'Merge time to time period': 4,
#  u'Efficiently creating a Pandas DataFrame Column that contains the instance number of a value in another column': 2,
#  u'Calling agg without first calling groupby': 1,
#  u'DataFrame method for renaming axis': 1,
#  u'Datetime comparison within Pandas messing with datetime.time()': 1,
#  u'dynamically rename data frame in Python': 2,
#  u'Removing header column from pandas dataframe': 1,
#  u'Getting Unusual error with Pandas for a regression learning program in python': 0,
#  u'Natural language date differences in python': 1,
#  u'Concatenating multiple data dictionaries in python': 1,
#  u'How to check if certain values exist in a time window using Python': 1,
#  u'Replace missing values that result from a pandas merge': 2,
#  u'Drop Multi-index and auto rename columns': 2,
#  u'pandas apply individual logic to group': 1,
#  u'Counting total number of element occurrences in different length vectors': 2,
#  u'Drop dataframe rows which are missing in an intersection with another dataframe': 1,
#  u'Stack columns in pandas dataframe to achieve record format': 1,
#  u'How can one create dummy variables in pandas that do not have multicollinearity?': 1,
#  u'map pandas Dataframe columns to dictionary values': 2,
#  u'Slicing Series in pandas': 1,
#  u'Conditional function on multiple rows': 1,
#  u'Reading table data (card images), with format specifier given, into Python': 1,
#  u'Pandas resample OHLC': 1,
#  u'PANDAS merge content of multiple cells wrt to an index': 2,
#  u'Assign new value in DataFrame column based on group max': 1,
#  u'Pandas find first nan value by rows and return column name': 2,
#  u'reindex sorted pandas dataframe': 1,
#  u'Python: Plotting Slices of Time Series': 2,
#  u'How to concat Pandas dataframe columns': 1,
#  u'How to get integers instead of floats from DataFrame&#39;s rank method': 1,
#  u'Python pandas objects as COM variants?': 0,
#  u'Load CSV Strings With Different Types into Pandas Dataframe, Split Columns, Parse Date': 1,
#  u'argmin in dataset containing NaN python': 1,
#  u'How to get match result by given range using regular expression?': 2,
#  u'append all column in list - pandas': 1,
#  u'Pandas Mapping Multiple Column Function on a DataFrame': 2,
#  u'Cannot get pandas to open CSV [Python, Jupyter, Pandas]': 0,
#  u'searching matching string pattern from dataframe column in python pandas': 1,
#  u'Optimize Python code. Optimize Pandas apply. Numba slow than pure python': 1,
#  u'how to merge pandas dataframe with different lengths': 2,
#  u'How to make matplotlib/pandas bar chart look like hist chart?': 1,
#  u'Running sentiment analysis on a single column in a Dataframe': 0,
#  u'remove control character whitespaces from dataframe': 1,
#  u'How to subset a dataframe and resolve the SettingWithCopy warning in Python?': 1,
#  u'Python Pandas v0.18+: is there a way to resample a dataframe without filling NAs?': 1,
#  u'Exporting a random sample from CSV file to a new CSV file - output is messy': 2,
#  u'error importing python packages -- anaconda': 0,
#  u'Repeating columns in DataFrame': 2,
#  u'pandas: finding first incidences of events in df based on column values and marking as new column values': 1,
#  u'Using Pandas to Create DateOffset of Paydays': 1,
#  u'strftime function pandas - Python': 1,
#  u'Python/Pandas dataframe - return column name': 1,
#  u'Create minutely date_time range using Pandas': 1,
#  u'Python Pandas: How can I group by and assign an id to all the items in a group?': 1,
#  u'Turn an Excel spreadsheet into an array': 1,
#  u'How can a pandas groupby .sum return wrong values?': 2,
#  u'Pandas time series resampling': 1,
#  u'Pandas error converting string to datetime': 1,
#  u'How do I replace all values equal to x in nth level of a multi index': 2,
#  u'Conditional searches on pandas Dataframe': 1,
#  u'How do I convert greyscale images represented as strings of space separated pixel values to column of features to train a classifier in scikit-learn?': 2,
#  u'PANDAs create ordinal ascending value column within Group': 2,
#  u'python &amp; pandas: iterating over DataFrame twice': 1,
#  u'Pandas: Create another column while splitting each row from the first column': 4,
#  u'how to get the shifted index value of a dataframe in Pandas?': 2,
#  u'Include two different sized data frames together in a pandas panel': 1,
#  u'Pandas .groupby(): aggregation to include grouping variable': 1,
#  u'Find Specific Cell in Pandas Dataframe Then Fill new column with it': 1,
#  u'Slicing pandas dataframe by looking for character &quot;in&quot; string': 1,
#  u'Pandas: Creating new data frame from only certain columns': 1,
#  u'Performance of looping with pandas': 1,
#  u'Pandas read_csv with chunksize is skipping data': 1,
#  u'Pandas time series - join by closest time': 1,
#  u'Speeding up the light processing of ~50GB CSV file': 3,
#  u'pandas plot - multiple colorbars': 1,
#  u'Convert datatime to milliseconds since midnight UTC or localized in CSV file using Pandas': 1,
#  u'creating pandas multiindex based on CustomBusinessHour start': 1,
#  u'Compare columns of 2 different Data frames': 1,
#  u'Replace NaNs with some multiple of previous value in Pandas Dataframe': 2,
#  u'Importing text file : No Columns to parse from file': 2,
#  u'Python (pandas) - reset index with count': 1,
#  u'How can I add a constant percentage to each wedge of a pie chart using matplotlib': 2,
#  u'ValueError: could not convert string to float: yes while fitting a model using gridsearch from scikit learn': 0,
#  u'Groupby a data set in Python': 2,
#  u'How to update dataframe value': 2,
#  u'Python Pandas alterates values in floating point': 1,
#  u'Date&#39;s difference using diff()': 1,
#  u'Counting/assigning group order to observations within groups for multilevel groups?': 1,
#  u'.annotate() is not plotting all labels': 1,
#  u'How to multiply to each value in each element in SArray in Python?': 3,
#  u'Python Pandas, one dict column, create new rows for each key/value pair': 1,
#  u'Why is my linear regression data summary displaying the wrong information?': 0,
#  u'Pandas: build pivot table': 0,
#  u'Boolean filter using a timestamp value on a dataframe in Python': 1,
#  u'Remove or empty all data from a pandas dataframe': 1,
#  u'Pandas table lookup': 1,
#  u'In pandas, how to get average of several column values for each row in data frame while accounting for missing data/varying number of columns?': 1,
#  u'How to append iteration (from each iter.) results to final Dataframe containing all iteration results?': 1,
#  u'Pandas and Cassandra: numpy array format incompatibility': 1,
#  u'Using a shift() function within an apply function to compare rows in a Pandas Dataframe': 2,
#  u'groupby and add some rows': 1,
#  u'Pandas stacking DataFrame and concatenating name of columns with index': 1,
#  u'python xlsxwriter: Keep header in excel when adding a table': 2,
#  u'Pandas Create Column with Groupby and Sum with additional condition': 1,
#  u'Plotting individual bar graphs for each index of a Pandas dataframe': 1,
#  u'pandas - linear regression of dataframe columns values': 1,
#  u'Python SqlAlchemy | Issue on CSV bulk insert in MySQL': 0,
#  u'Better way to implement `df[m] = df[x] + df[y] + df[z]`': 2,
#  u'How can I get the corresponding features back?': 1,
#  u'Converting a string with list of dicts to pandas df': 1,
#  u'Python: Groupby hour include null values': 1,
#  u'Getting columns from .json file': 1,
#  u'pandas convert object type to float': 1,
#  u'Parsing text into it&#39;s own field, counting, and reshaping select fields to wide format': 2,
#  u'Changing the value of elements in a series of a dataframe python': 1,
#  u'Summing a column in Pandas Groupby': 1,
#  u'Merging two dataframes with same index in pandas': 1,
#  u'Scatter and Hist in one subplot in Python': 1,
#  u'pandas distinction between str and object types': 1,
#  u'Plotting pandas dataframe with microseconds resolution': 1,
#  u'Convert part of data frame into MultiIndex in Pandas': 1,
#  u'How reading data with pandas.read_csv containing time AM/PM format?': 1,
#  u'Function that calculates the 80th percentile for a pandas dataframe': 2,
#  u'Pandas timestamp conversion': 2,
#  u'Check if the Cells of a Column Begin With a Specific String [Pandas]': 1,
#  u'How to Replace All the &quot;nan&quot; Strings with Empty String in My DataFrame?': 4,
#  u'add timestamps related fields from existing unix timestamp field dataframe in python': 1,
#  u'How to increment dataframe with pandas?': 0,
#  u'Get next value from a row that satisfies a condition in pandas': 1,
#  u'How do I edit default index values for x positions in matplotlib bar chart': 2,
#  u'pandas to loop through DataFrames and keep only specified column headings. Error results if specified heading is not in DataFrame': 2,
#  u'Subsetting column from pandas dataframe with indexing': 1,
#  u'Writing long list using pandas to save in csv files': 1,
#  u'Select rows in pandas matching time condition': 1,
#  u'python open(): [Errno 13] Permission denied: / Pandas read_csv: File does not exist - but file exists': 0,
#  u'How to group and printing unique values of Column-B wrt to Column-A in pandas?': 2,
#  u'Rounding up decimals Python': 2,
#  u'Converting from Deep to wide format in pandas without Memory errors': 1,
#  u'Python: Counting cumulative occurrences of values in a pandas series': 2,
#  u'Inconsistent Immutability of Python Index': 1,
#  u'Concatenating all Possible Column Values of Other Unique Column': 1,
#  u'pandas replace inner workings': 1,
#  u'&#39;B&#39;: &quot;{:0&lt;4.0f}&quot; | How should I read this?': 3,
#  u'pandas: Calculate percentile by row and gracefully handle non-unique values?': 2,
#  u'How to order and keep common indexes from two DataFrames': 2,
#  u'Nearest Date in a Column': 1,
#  u'Pandas: Need a speedier way of index slicing': 3,
#  u'pandas str contain to return match': 1,
#  u'Pandas Axis Order Inconsistency': 0,
#  u'Set of repeated NaNs in pandas Series': 2,
#  u'Pandas.plot(kind = &#39;bar&#39;) returns line plot': 1,
#  u'Combine similar rows to one row in python dataframe': 1,
#  u'Convert Sparse Pandas DataFrame to Dense DataFrame': 2,
#  u'How to speed up resample procedure in Pandas?': 1,
#  u'is_max = s == s.max() | How should I read this?': 5,
#  u'Sending pandas dataframe to java application': 1,
#  u'sklearn Linear Regression coefficients have single value output': 2,
#  u'How to count duplicate rows in pandas dataframe?': 2,
#  u'Sort dataframe rows independently by values in another dataframe': 1,
#  u'Convert a list of values to a time series in python': 2,
#  u'Using pandas.dataframe.pivot_table with non-numeric, non-unique values': 1,
#  u'How to concat and update pandas dataframes': 1,
#  u'Python: nested lists, extend &amp; delete elements': 1,
#  u'I need to change the format of the current Dataframe. How should i do this?': 1,
#  u'Python pandas dataframe sort_values does not work': 2,
#  u'How to do arithmetic on tidy data in pandas?': 2,
#  u'Python Pandas Dataframe: Normalize data between 0.01 and 0.99?': 1,
#  u'PANDAS TimeGrouper with individualized starting point for downsample': 1,
#  u'Find column with the highest value (pandas)': 1,
#  u'Pandas_datareader not working in script?': 1,
#  u'Converting Tuple Index to a Datetime index': 2,
#  u'Pandas plot series with series names in one row': 1,
#  u'Calculate every 5 minute returns using 1 minute data in pandas dataframe': 1,
#  u'How to know what is being written in Python during import module?': 1,
#  u'compare dataframes by values': 1,
#  u'Pandas DataFrame plotting - Tick labels': 1,
#  u'matlab data file to pandas DataFrame': 2,
#  u'AttributeError: &#39;str&#39; object has no attribute &#39;to_datetime&#39;': 1,
#  u'Indexing in order to calculate with columns in Python pandas dataframe': 1,
#  u'Replaces spaces with NAN in pandas dataframe': 3,
#  u'DataFrame in list boolean?': 1,
#  u'How can I add a column of one Dataframe (in pandas) to another Dataframe, corresponding to the values of a certain column in each?': 0,
#  u'Dato: What&#39;s the equivalent function for graphlab.random_split() in pandas?': 3,
#  u'Pandas: delete string with some date': 1,
#  u'Pandas: replace empty cell to 0 when write to file': 1,
#  u'Create a JSON file from a Flask view to be used with D3': 1,
#  u'How do I concatenate columns in two pandas dataframes with different indexes and non-unique keys': 1,
#  u'Error while parsing out few fields from dictionary to CSV': 2,
#  u'f() with functools.partial to do a groupby with multiple parameters': 0,
#  u'drop hour,min,sec from timestemp?': 2,
#  u'All indices of each unique element in a list python': 2,
#  u'Copy pandas DataFrame row to multiple other rows': 1,
#  u'Handling a very big dataframe': 1,
#  u'Can you split out datetime months in Pandas?': 3,
#  u'Catching Errors in Python MultiProcessing Pool Map': 1,
#  u'Dividing cell values in the column by column values in a different data table': 1,
#  u'pandas histogram with by: possible to make axes uniform?': 1,
#  u'Identifying Consecutive Sequences of Data and Counting their Lengths': 1,
#  u'move column in pandas dataframe': 2,
#  u'Python pandas column asignment between dataframe and series does not work': 1,
#  u'How to drop duplicates in dataframe ignoring whitespaces?': 2,
#  u'Turning table data into columns and counting by frequency': 1,
#  u'pd.read_html() imports a list rather than a dataframe': 1,
#  u'Python: how to separate time records(e.g. 2015-02-01 12:34:22) in to two different arrays': 1,
#  u'Pandas SQL equivalent of update where group by': 3,
#  u'pandas.DataFrame set all string values to nan': 3,
#  u'Quickest way to calculate subset of correlation matrix': 1,
#  u'Binning by value, except last bin': 1,
#  u'Pandas expand rows from list data available in column': 1,
#  u'pandas.io.common.CParserError: Error tokenizing data. C error: Buffer overflow caught - possible malformed input file': 1,
#  u'Pandas: Is there a way to use something like &#39;droplevel&#39; and in process, rename the the other level using the dropped level labels as prefix/suffix?': 2,
#  u'Dataframe with many punctuation marks to csv using python3': 0,
#  u'Trouble using pandasql to run simple query in Python': 0,
#  u'how to convert a (possibly negative) Pandas TimeDelta in minutes (float)?': 2,
#  u'Concatenate values of 2 columns into 1 (equivalent of R&#39;s paste)': 1,
#  u'Calculating cosine similarity across column in pandas': 1,
#  u'Pandas Dataframe automatically shorten strings?': 1,
#  u'Why am I getting NaN when I join two DataFrame that have no NaN in them (multilevel index)?': 2,
#  u'Utilize multiple cores for Pandas': 1,
#  u'Pandas dataframe merge on rows': 1,
#  u'Using pyinstaller with pandas': 0,
#  u'TypeError when converting Pandas to Spark': 1,
#  u'Pandas: Subtract rows in dataframe': 1,
#  u'python pandas dataframe index match': 2,
#  u'How to convert a particular dtype object column&#39;s field into column of data frame in pandas': 1,
#  u'pandas: find percentile stats of a given column': 2,
#  u'Interpolate (upsample) non-equispaced timeseries into equispaced with Pandas version 18.0rc1': 1,
#  u'Switch-case like structure in python': 2,
#  u'Drop multi-indexed rows of a DataFrame based on &#39;AND&#39; condition between levels': 2,
#  u'API Call - Multi dimensional nested dictionary to pandas data frame': 1,
#  u'what is the difference between these two ways of filtering a pandas dataframe for sklearn classifier?': 1,
#  u'Find the low/high value before finding high/low value in a Pandas Dataframe': 0,
#  u'What would be wrong with this function that return a rounded number in millions': 1,
#  u'How to find rows that differ by only one column in pandas?': 1,
#  u'Probability of next day being specific values using Python Pandas': 1,
#  u'Python: get request using urlparse in utf-8': 0,
#  u'concat a DataFrame with a Series in Pandas': 1,
#  u'seaborn heatmap using pandas dataframe': 1,
#  u'Adding a column to a Multiindex Dataframe': 1,
#  u'Pandas function for generating series from dataframe': 1,
#  u'In pandas, How to select the rows that contains NaN?': 1,
#  u'Add a new value to a field with a for loop, and keep the original value': 1,
#  u'pandas groupby resample unexpected result': 1,
#  u'Pandas using datarange to get day of week for each date': 2,
#  u'Select data from HDFStore table based on value when column name is integer': 0,
#  u'Iterating Through Timeseries One Day at a Time': 1,
#  u'Python pandas plot more columns but shows only one legend': 1,
#  u'Pandas DataFrame with MultiIndex: Slice by specific year from DateTime level values': 0,
#  u'Non-conformable arrays in quantile regression model from pandas DataFrame using rpy2': 1,
#  u'How to convert DatetimeIndexResampler to DataFrame?': 0,
#  u'Python pandas &#39;ffill&#39; method not working': 1,
#  u'iterating dataframe coulmns after groupby': 1,
#  u'numpy matrix to pandas Series': 1,
#  u'python I want to set_index dateFrame with datetime': 3,
#  u'How to read only some lines from a large file in python?': 3,
#  u'Pandas series - only keep value if index month is in [1,2,3]': 1,
#  u'Dataframe is not updated when columns are passed to function using apply': 1,
#  u'subclassing pandas Series and DataFrame: When combining subclassed series into subclassed data frames, the series loose metadata': 0,
#  u'How to merge two csv files using multiprocessing with python pandas': 1,
#  u'How to write a construction of code as a function': 1,
#  u'How to add x seconds to a Python datetime64[ns] field?': 1,
#  u'subselect pandas dataframe based on index': 1,
#  u'Python Pandas Adding to Dataframe': 2,
#  u'Pandas row to json': 1,
#  u'Running total of consecutive identical values': 2,
#  u'Why is Pandas converting datetimes to float in aggregate function': 2,
#  u'Splitting a large Pandas Dataframe with minimal memory footprint': 3,
#  u'How to get row, column indices of items in Pandas dataframe': 3,
#  u'how to reduce the time of python import modules?': 0,
#  u'Count time to some event using pandas': 1,
#  u'Pandas - How to store result of duplicated method as boolean in a new column?': 1,
#  u'Pandas Groupby TimeGrouper and apply': 1,
#  u'Why AttributeError occurs in DataFrame.apply() but not in individual function call?': 1,
#  u'Pandas merge only return column names': 1,
#  u'How to not include last value using rolling in Pandas?': 1,
#  u'Deleting rows in pandas dataframe where label count &gt; 2': 1,
#  u'Pandas: Charting 3 months of quotes with a benchmark': 1,
#  u'Multiply each value in two data frames and add each answer to a column': 1,
#  u'Pandas: Average over the same hour': 1,
#  u'Python 3.x - Extract string from data frame': 1,
#  u'Use series to get at value in dataframe': 3,
#  u'Keeping domain of Email but removing TLD': 4,
#  u'With a gzip dataframe, how can I read/decompress this line by line?': 3,
#  u'Python pandas read_csv dtype object empty csv': 0,
#  u'read_csv with parse_date not recognising dates?': 1,
#  u'How to return correctly formatted pandas dataframe from apply?': 2,
#  u'Best way to calculate weighted average percent in a pandas dataframe for a heatmap?': 0,
#  u'Python pandas check if dataframe is not empty': 2,
#  u'pandas: error on DataFrame.unstack': 1,
#  u'Emulating the behaviour of loc in composited module': 0,
#  u'pandas dataframe get rows based on matched strings in cells': 2,
#  u'How to classify the numbers by value in DataFrame': 2,
#  u'How to make pandas#read_csv raise exception when some columns missed': 1,
#  u'Extraneous empty row after header': 1,
#  u'pandas - Merging on string columns not working (bug?)': 1,
#  u'How to perform a OLS regression on dynamic data frame and estimate the slope coefficient?': 1,
#  u'GroupBy - How to extract seconds from DateTime with diff()': 1,
#  u'Python pandas dataframe- remove columns from header': 1,
#  u'python pandas - simultaneously map and insert column to specific index': 1,
#  u'Ploting two barplots side by side': 2,
#  u'Groupby on categorical column with date and period producing unexpected result': 1,
#  u'optimising a pandas join/finding more memory efficient way': 0,
#  u'plot multiple points using Pandas data frame': 0,
#  u'Slicing DataFrame by duplicate period indexes in Pandas': 0,
#  u'Pandas: append dataframe to another df': 1,
#  u'Python pandas tensor access is extremely slow': 1,
#  u'What is the best way to create new columns based on value of existing column of Pandas dataframe in Python?': 1,
#  u'Resampling and Normalizing Irregular Time Series Data in Pandas': 2,
#  u'Turn pandas series to series of lists or numpy array to array of lists': 4,
#  u'How to plot age distribution with pandas': 1,
#  u'Pandas to_dict group all non index columns into a list of tuples': 1,
#  u'Incorrect time/time zone after sorting, grouping, and reindexing pandas dataframe': 0,
#  u'python pandas dataframe merge or join dataframe': 1,
#  u'pandas: t-test and p-value of month over month mean difference in aggregated dataframe using groupby function': 2,
#  u'How transform value pandas dataframe?': 1,
#  u'Python: UserWarning: This pattern has match groups. To actually get the groups, use str.extract': 1,
#  u'Concatenate a set of column values based on another column in Pandas': 1,
#  u'Efficient lookup by common words': 5,
#  u'How to convert MATLAB timestamps into real datatime in python?': 0,
#  u'How to slice pandas DataFrame based on values from another Dataframe without using for-loop?': 1,
#  u're-naming data frame output given input parameter to class in python': 2,
#  u'Manipulating Data Frames in Python(Pandas)': 3,
#  u'Convert Pandas DataFrame to Dictionary using multiple columns for the key': 1,
#  u'Storing list in a pandas DataFrame column': 1,
#  u'efficient function to find harmonic mean across different pandas dataframes': 1,
#  u'Ignore np.where after first match for Pandas time series data': 2,
#  u'Reading Json file as Pandas Dataframe error': 1,
#  u'Get nearest time value and convert format': 1,
#  u'Trying to loop over colums in DataFrame and strip Dollar Sign': 1,
#  u'Title using matplotlib and pandas - python': 1,
#  u'Nested Pandas dataframe - How to select / group by data?': 3,
#  u'Get Subset of MultiIndex Pandas DataFrame with Single Index Boolean Indexer': 1,
#  u'Key error when selecting columns in pandas dataframe after read_csv': 1,
#  u'Difficulty to create a function groupby in python': 0,
#  u'pandas.concat of multiple data frames using only common columns': 1,
#  u'Getting Pandas Dataframe in correct format for Seaborn swarmplot': 1,
#  u'how to set the primary key when writing a pandas dataframe to a sqlite database table using df.to_sql': 0,
#  u'Importing images for manifold Isomap': 1,
#  u'python pandas-how to apply function according to another column&#39;s value': 1,
#  u'Adding Keyword with count of occurrence in sheet2 to existing excelfile from sheet1 with pandas python': 2,
#  u'Pandas pd.cut Field Where Other Field Equals Value': 1,
#  u'Error iterating through a Pandas series': 2,
#  u'How can I split a DataFrame column with datetimes into two columns: one with dates and one with times of the day?': 3,
#  u'How to append a suffix for specific column names of a dataframe from a list': 2,
#  u'How to groupby time series data': 2,
#  u'pandas - add a column of the mean of the last 3 elements in groupby': 1,
#  u'Plotting concatenated pandas dateframe': 0,
#  u'how to create or update a column': 1,
#  u'Creating a Pandas dataframe with two adjacent columns of predicted and actual values': 1,
#  u'Normalising KDE plots': 0,
#  u'pandas: index out of bounds using ix, but I can see the column': 2,
#  u'append a row to a dataframe': 2,
#  u'Pandas SQLalchemy: complex filter on database columns': 1,
#  u'Python pandas extract, how to extract remaining part of string': 1,
#  u'How to graph Residual Values using numpy.linalg.lstsq?': 0,
#  u'In Pandas crosstab operation, setting both colnames=[None] and margins=True causes error': 0,
#  u'Grouping numerical values in pandas': 2,
#  u'Multiply dataframes with differnet lengths regarding columns names': 2,
#  u'numpy array converted to pandas dataframe drops values': 2,
#  u'Select dictionary elements in a Pandas series': 0,
#  u'How to split dataframe according to intersection point in Python?': 1,
#  u'convert &quot;1h30min&quot; string to minutes in python': 3,
#  u'Store the counts for a specific value in a column in Pandas dataframe': 2,
#  u'Python: write df to json': 1,
#  u'Error with matplotlib and pandas on Jupyter Notebook Mac OS': 1,
#  u'Resample in pandas without changing date': 2,
#  u'How to apply a function to only one row': 1,
#  u'Pandas: calculate average number of rows per user per day': 4,
#  u'Slice column in panda database and averaging results': 2,
#  u'Open files with pandas using relative path?': 2,
#  u'Concat two Pandas dataframes without sorting on initial columns': 1,
#  u'How to check if 2-D array is in another 2-D array': 2,
#  u'Bokeh line plot is merging data on graph': 1,
#  u'Adding headers to processed dataframe in Panda&#39;s': 1,
#  u'Appending variable length columns in Pandas dataframe Python': 1,
#  u'python adjust x-axis label frequency': 1,
#  u'Delete rows from pandas DataFrame with non-unique index': 2,
#  u'Creating multiple spreadsheets in one excel file with Python Pandas': 1,
#  u'Is it okay to use common abbreviations as variable names in Python?': 3,
#  u'Convert pandas python data frame column values in place': 3,
#  u'How to remove multi indexing from a pandas pivot table for easy visualisation': 1,
#  u'PANDAS DROP ROWS based on filtered items, my solution - not satisfied': 1,
#  u'Pandas MultiIndex: How to remove entire level that has zero positive values in specific column?': 1,
#  u'parsing nested JSON into multiple dataframe using pandas python': 1,
#  u'Pandas read_table error': 1,
#  u'SQL iterate over distinct values of a column and build a data frame for each value': 4,
#  u'Filter Data Frame by dates in another dataframe': 1,
#  u'Creating pandas data frame with index with values in different sizes': 1,
#  u'Moving average by id/group with a defined interval in python': 1,
#  u'How to make a function for groupby based on number of inputs from user?': 1,
#  u'Adding Column Headers to new pandas dataframe': 2,
#  u'Join on two SQLite databases python/pandas': 0,
#  u'kNN Classifier - importance of DataFrame column order - is this a scikit bug, pandas bug or by design?': 1,
#  u'Subsetting stacked pandas dataframe': 1,
#  u'How may I merge a dataframe with repeated index entries with one with unique index entries?': 1,
#  u'Converting DateTime format of Excel into DateTime Pandas': 1,
#  u'How to isolate parts of pandas data frame': 1,
#  u'Looking up values of one csv file in another csv file and print the row': 1,
#  u'Calculate possible date combination without year': 1,
#  u'How to skip several rows in pandas': 1,
#  u'Split one column of csv file based on another column': 1,
#  u'Calculating subtotals in pandas pivot_table with MultiIndex': 1,
#  u'Can I create a new column based on when the value changes in another column?': 1,
#  u'Pandas Insert a row above the Index and the Series data in a Dataframe': 1,
#  u'skflow pandas dataset mean down each 2 lines': 1,
#  u'Pandas concatenation of multiple dataframes returns null values': 1,
#  u'Using multiprocessing with google analytics app engine calls with python, pandas': 0,
#  u'How to pass a parameter to only one part of a pipeline object in scikit learn?': 1,
#  u'Matplotlib: Overriding &quot;ggplot&quot; default style properties': 1,
#  u'Merging with more than one level overlap not allowed': 1,
#  u'read_hdf where fails &#39;all of the variables refrences must be a reference to an axis...&#39;': 1,
#  u'Pandas- Removing duplicate rows based on the columns': 1,
#  u'Transform rows of pandas Dataframe into list of strings': 1,
#  u'python, pandas, csv import and more': 1,
#  u'Pandas one row pitvot table returns a serie instead of data frame': 2,
#  u'Error in axis.set in matplotlib': 1,
#  u'Rotation labels matplotlib': 1,
#  u'How to do iterations to change dummy variable in multiple columns from 1 to 0 in Python and Pandas?': 1,
#  u'Bokeh: chart from pandas dataframe won&#39;t update on trigger': 1,
#  u'How to speed-up the replacement of missing values for each groupby group in Pandas?': 3,
#  u'How to sort dataframe by a row?': 4,
#  u'Tricky error when selecting the rows by certain value': 1,
#  u'column (in index format) to dataframe?': 1,
#  u'Pandas replace multiple values at once': 2,
#  u'Write data from a df to an excel workbook that already has other worksheets': 1,
#  u'AttributeError: module &#39;mypandas&#39; has no attribute &#39;print_pandas_df&#39;': 1,
#  u'ValueError: time data &#39; 1:00:00&#39; does not match format &#39;%H:%M:%S&#39;': 1,
#  u'Python Pivot Table without Pandas?': 1,
#  u'Compare two columns of two different dataframes': 1,
#  u'How to use if statements to assign values to new column in python?': 1,
#  u'Numpy .shuffle gives the same results each time': 1,
#  u'How to group all review texts of each item together with python-pandas?': 1,
#  u'Search for a combination in dataframe to change cell value': 2,
#  u'Pandas compare 2 dataframes by specific rows in all columns': 3,
#  u'OneVsOneClassifier fails with pandas DataFrame': 0,
#  u'Remove last two characters from column names of all the columns in Dataframe - Pandas': 1,
# ...
#  u'How to deal with data with pandas without influencing nan?': 1,
#  u'Summary data for pandas dataframe': 1,
#  u'Complex data transformation in Python': 1,
#  u'Getting correct exogenous least squares prediction in Python statsmodels': 1,
#  u'giving a name to a pandas dataframe?': 1,
#  u'How to python pandas.DataFrame.fillna(method=&#39;pad&#39;) left to right?': 0,
#  u'Removing values in dataframe once threshold (min/max) value has been reached with Pandas': 2,
#  u'Merging pandas dataframes duplicates some data': 1,
#  u'How to execute a multi-threaded `merge()` with dask? How to use multiples cores via qsub?': 1,
#  u'Suming in Pandas after and before nth rows': 1,
#  u'how to extract numeric information from a string in Pandas?': 1,
#  u'How to print DataFrame on single line': 1,
#  u'Getting a sane default date axis in matplotlib': 1,
#  u'Multiple conditional average python': 1,
#  u'Random selection in pandas dataframe': 1,
#  u'Apply a function to pandas dataframe and get different sized ndarray output': 1,
#  u'Creating different columns in dataframe from a key pair in a dictionary': 3,
#  u'Parse custom XML to JSON or Pandas DataFrame. (Python)': 1,
#  u'how to initialize multiple columns to existing pandas DataFrame': 2,
#  u'Names are not displaying on csv from dataframe in python but do in console': 0,
#  u'Pandas: Memory Error when merging dfs': 0,
#  u'How to print a df in Terminal without loosing format?': 2,
#  u'Pandas bin and count': 2,
#  u'incorrect date format when writing df to csv pandas': 1,
#  u'Trying to bin data in Pandas, but always stops after certain row': 1,
#  u'Get distinct datatypes within the same Series in Pandas': 2,
#  u'how to compute quantile bins in Pandas when there are ties in the data?': 1,
#  u'How to sample data by keeping at least two non zero columns': 2,
#  u'Converting / parsing column strings to datetime values - pandas': 1,
#  u'How to transform a Python tuple to a .csv file?': 3,
#  u'Pandas Single Timestamp with index of offsets': 1,
#  u'Groupby Aggregate method is returning NaN always': 1,
#  u'How to build Pandas DataFrame table using formulas?': 0,
#  u'log2 axis doesn&#39;t work for histograms in matplotlib/seaborn': 1,
#  u'Extract dictionary value from column in data frame': 5,
#  u'How do I sort a subset of column names n Pandas based on a condition?': 0,
#  u'Speed up creation of numpy array from list': 2,
#  u'How to get row percentages with pandas crosstab in a three-way table?': 1,
#  u'Concatenate or Average A Dataframe In A Function': 0,
#  u'pandas group by confusion -- unhashable type': 1,
#  u'How to melt/stack a 2-factorial multivariate DataFrame from wide to long format?': 1,
#  u'Representing and rounding currency in python pandas': 1,
#  u'Initilize multiple dataframe columns with categorical labels': 1,
#  u'GeoPandas unable to read in PostGIS table': 0,
#  u'A more efficient way of repeating pandas rows for each row in another data frame?': 1,
#  u'R foverlaps equivalent in Python': 1,
#  u'accelerating the data generation process': 0,
#  u'graphviz: how to produce a decision tree': 0,
#  u'How to speed up the group by and IO with python-pandas?': 0,
#  u'python str() and unicode() producing different results in pandas dataframe': 0,
#  u'pandas subtract two sets of data': 1,
#  u'Group by pandas': 2,
#  u'How to create histogram from grouped data': 1,
#  u'How to apply a randomforest classifier to all of the dataset, a small section at a time in python': 2,
#  u'In Pandas, how to convert a string to a datetime object with milliseconds?': 2,
#  u'Group by min of date in pandas dataframe, returning nanoseconds not days': 1,
#  u'Pandas pivot_table do not comply with values order': 1,
#  u'Pandas - Select rows based on other rows': 1,
#  u'groupby multiple value columns': 3,
#  u'Possible for pandas dataframe to be rendered in a new window?': 1,
#  u'Part II: Counting how many times in a row the result of a sum is positive (or negative)': 1,
#  u'Finding subset of dataframe rows that maximize one column sum while limiting sum of another': 2,
#  u'alpha &amp; beta (for linear regression) calculations output nan?': 3,
#  u'Python ggplot histogram binwidth and bins arguments not working': 0,
#  u'different amount of rows after merging two dataframes with pandas': 2,
#  u'In columns containining &#39;X&#39;, check for and delete rows containing &#39;Y&#39;': 2,
#  u'A dict of pandas dataframes: how to know if referencing a copy of the dataframe in the dict or the dataframe inside the dict?': 1,
#  u'Pandas: print column name with missing values': 3,
#  u'Does Python&#39;s DataReader count as an API?': 1,
#  u'Merging data frames while excluding empty records': 1,
#  u'How to calculate day&#39;s difference between successive pandas dataframe rows with condition': 1,
#  u'Pandas Multiindex selecting list of columns from given level': 2,
#  u'pandas reading csv file encoding error': 1,
#  u'Python Pandas with sqlalchemy | Bulk Insert Error': 1,
#  u'Pandas: &#39;Value set in a copy of slice from df&#39; error when performing groupby': 0,
#  u'feather data storage library for python &#39;module&#39; object has no attribute &#39;write_dataframe&#39; error': 0,
#  u'Find rows that have same values in another column - Python': 1,
#  u'Sorting df rows horizontally': 2,
#  u'Dataframe.shape very slow on medium size data': 0,
#  u'Trying to use pandas pivot like excel pivot': 1,
#  u'prevent sorting of column names in pandas - python': 2,
#  u'Pandas extract multiple columns': 1,
#  u'how to get the next index of a specific index in pandas?': 0,
#  u'Chaining grouping, filtration and aggregation': 2,
#  u'Create pandas DateTimeIndex from 12-hour-clock format': 2,
#  u'How to plot a value_counts in pandas that has a huge number of different counts not distributed evenly': 2,
#  u'Using logistic regression for a multiple touch response model (python/pandas)?': 1,
#  u'Pandas : saving Series of dictionaries to disk': 1,
#  u'Python - Convert strings in column into categorical variable': 1,
#  u'dummy variables in pandas based on values': 1,
#  u'Return the corresponding value in multiple columns Pandas': 1,
#  u'Create a hierarchical index from a .tsv file (pandas)': 1,
#  u'Subtract series value from pandas data frame given multiple index': 2,
#  u'Select xarray/pandas index based on specific months': 1,
#  u'Python, Pandas: tz_localize AmbiguousTimeError: Cannot infer dst time with non DST dates': 0,
#  u'Selenium pull HREF out of TD in table': 2,
#  u'How to sort groupby and filter using pandas': 1,
#  u'Working with JSON Nested in JSON Using Python/Pandas': 1,
#  u'Regular expression python dataframe element': 2,
#  u'python Numpy transpose and calculate': 2,
#  u'How to change rows to columns by date in pandas?': 1,
#  u'Pandas: Append rows to DataFrame already running through pandas.DataFrame.apply': 1,
#  u'How do I scale xtick values axis in pyplot': 1,
#  u'How can I use Pandas to round inconsistent timestamps to five minute intervals and fill gaps?': 1,
#  u'Memory is never released when opening pandas data frame in ProcessPoolExecutor': 0,
#  u'How to change multiple Pandas DF columns to categorical without a loop': 2,
#  u'Python function for MA and MACD has &quot;ValueError: negative dimensions are not allowed&quot;': 1,
#  u'Fill missing values from another Pandas dataframe with different shape': 1,
#  u'How do I convert a MultiIndex to type string': 4,
#  u'Pandas DataFrame Self-Join on Key1 == Key1 and Key2 +1 == Key2': 1,
#  u'Stacked Lines in Pandas': 1,
#  u'Interactive/Animated scatter plotting with matplotlib': 1,
#  u'plot pandas period_range with matplotlib - set freq of axis': 1,
#  u'Filter DataFrame rows that are lists': 1,
#  u'Adding Probability to the predicted value': 1,
#  u'Pandas create multiple aggregations': 2,
#  u'Conda Pandas install on Ubuntu doesn&#39;t install C extension': 0,
#  u'Iterate through values of dataframe': 1,
#  u'Create monthly pandas DatetimeIndex': 1,
#  u'Divide part of a dataframe by another while keeping columns that are not being divided': 1,
#  u'Counting occurrence of a gender in a dataframe by age': 1,
#  u'Error: The truth value of a series is ambiguous. Python &amp; Pandas': 1,
#  u'pandas: convert multiple categories to dummies': 1,
#  u'different colors for rows in barh chart from pandas dataframe python': 1,
#  u'Set Values for datetime Index Slices': 0,
#  u'Using Pandas Melt() to pivot on two sets of data': 1,
#  u'How to retrieve individual value from DataFrame': 1,
#  u'Pythonic way of creating a recursive series of 1 and 0 based on a pandas time series level': 3,
#  u'Transposing dataframe and sorting': 3,
#  u'Pandas column creation': 3,
#  u'Pandas read_csv keeps returning null columns': 1,
#  u'for loop to extract header for a dataframe in pandas': 1,
#  u'No module named &#39;numpy&#39;: Visual Studio Code': 1,
#  u'Convert DataFrame column type in datetime': 1,
#  u'Pandas.Dataframe.duplicated() includes missing rows as duplicates': 1,
#  u'Python: how to group pandas Data Frame in a certain time window?': 2,
#  u'How to append a string to int/float dataframes in Pandas': 2,
#  u'Verified Johansen Cointegration package in Python': 0,
#  u'get both unique count and max in group-by of pandas dataframe': 1,
#  u'Save one-hot-encoded features into Pandas DataFrame the fastest way': 1,
#  u'Lookup values with different column names in pandas': 1,
#  u'mean of absolute value of groupby object pandas': 2,
#  u'Pandas: transposing one column in a multiple column df': 1,
#  u'Multiple operations on Dataframe': 1,
#  u'Python Pandas: How to set Dataframe Column value as X-axis labels': 2,
#  u'What is Pandas doing here that my indexes [0] and [1] refer to the same value?': 1,
#  u'Python: using multiprocessing on a pandas dataframe': 2,
#  u'Pandas dataframe split by memory usage': 2,
#  u'H2OFrame converts dict to all zeros': 1,
#  u'Calculate percentiles/quantiles for a timeseries with resample or groupby - pandas': 1,
#  u'Filtering and Then Summing Groupby Data in Pandas': 2,
#  u'Pandas join without replacement': 1,
#  u'OpenPyxl Module Needed For DataFrames?': 0,
#  u'Apply a map to DataFrame rows which are NaN': 1,
#  u'Python pandas dataframe interpolate missing data': 2,
#  u'filling the missing points in the time series data with pandas.date_range and pandas.reindex python': 1,
#  u'How to rank plot in seaborn boxplot?': 2,
#  u'Python: how to efficiently convert multiple-level date variables into binary?': 0,
#  u'Python: read_csv into dataframe - can&#39;t convert object into float': 1,
#  u'pandas dataframe str.contains() AND operation': 5,
#  u'Filtering a panda dataframe based on value and time': 2,
#  u'How to use Python Web Scraping to download CSV file then convert it to Pandas Dataframe?': 1,
#  u'python &amp; pandas- Calculation bewteen rows based on certain values in columns from DataFrame': 2,
#  u'Extract non- empty values from columns of a dataframe in python': 1,
#  u'Pandas and Rolling_Mean with Offset (Average Daily Volume Calculation)': 1,
#  u'pandas How to find all zeros in a column': 1,
#  u'Python pandas: Select columns where a specific row satisfies a condition': 2,
#  u'Graphviz: vizualize data from a dataframe': 1,
#  u'Best way to convert R data.table to pandas.DataFrame?': 1,
#  u'TypeError: int() argument must be a string, a bytes-like object or a number, not &#39;DataFrame&#39;': 2,
#  u'Pandas: Groupby improvement': 0,
#  u'Isolating/manipulating data in a pandas Dataframe': 1,
#  u'0 index when generating excel xlsx file using pandas': 1,
#  u'rolling_sum on business day and return new dataframe with date as index': 1,
#  u'At what situation I can use Dask instead of Apache Spark?': 1,
#  u'Pandas: print pivot_table to dataframe': 1,
#  u'Speed up pandas dataframe lookup': 1,
#  u'Creating one dataframe from another (using pivot)': 1,
#  u'Group by year/month/day in pandas': 2,
#  u'Apply fuzzy matching across a dataframe column and save results in a new column': 1,
#  u'Python - pandas, DataFrame look like Nan but the behavior is like number': 0,
#  u'Suppressing Pandas dataframe plot output': 1,
#  u'Pandas inner product of rows': 2,
#  u'pandas df.apply TypeError data type not understood': 1,
#  u'How to load this dataset into Pandas': 1,
#  u'Pandas - How to group and unstack on multiple variables?': 2,
#  u'Substracting values from different DataFrame': 2,
#  u'Pandas Apply groupby function to every column efficiently': 1,
#  u'Time Series in Python 3.5 - Fitting ARMA model': 1,
#  u'python pandas groupby sorting and concatenating': 1,
#  u'Pandas calculate last few months data in new column': 1,
#  u'how to know when some operation on a dataframe affects the original data or not (so I need to reassign its name)?': 0,
#  u'Loading a very large txt file and taking transpose': 3,
#  u'pandas Series to Dataframe, use Series&#39; indexs as columns': 1,
#  u'Difficult Dataframe Reshape in Python Pandas': 3,
#  u'Plotting error bars matplotlib, using pandas data frame': 1,
#  u'Convert each cell of a Pandas&#39;s column from list to word-count dictionary?': 1,
#  u'Python Pandas returns different output for the same code': 0,
#  u'split dataframe and write new csv&#39;s based on loop': 1,
#  u'Dataframe - Sum Arrays in Cell - Memory Issue': 0,
#  u'cannot access excel file using Pandas Python': 2,
#  u'KeyError: &#39;Level None not found&#39;': 1,
#  u'Splitting a Pandas Data Frame into Rows by Count': 2,
#  u'Problems with special characters (\\r) when writing and reading csv files': 2,
#  u'Pandas Seaborn Heatmap Error': 1,
#  u'Python Pandas group by function': 2,
#  u'Change dataframe row names': 2,
#  u'How to create Panda Dataframe from csv that is compressed in tar.gz?': 2,
#  u'pandas calculate the counts and sum group by each category': 2,
#  u'How to calculate sum of Nth power of each cell for a column in dataframe?': 1,
#  u'Filter rows after grouping the data pandas python': 1,
#  u'How to calculate and add an FDR column to file in python': 0,
#  u'&#39;Unknown column&#39; error while importing pandas dataframe into mysql database': 0,
#  u'update dataframe with series': 1,
#  u'Pandas: find substring in a column': 1,
#  u'Classify the wind direction in several classes': 2,
#  u'How can I set a specific value to dataframe with a condition without warning in python pandas?': 1,
#  u'How to stack (per iteration) dataframes in column side by side in one csv file in python pandas?': 3,
#  u'Pandas Dataframe - Isolating values': 2,
#  u'read excel and convert index to datatimeindex pandas': 1,
#  u'how to change data type from byte to list when pulling data from api': 1,
#  u'Pandas.DataFrame - find the oldest date for which a value is available': 2,
#  u'Using Pandas DataFrame with Multi-name Columns': 1,
#  u'Iterating through DataFrame using pandas for stocks': 2,
#  u'Sum a column of values including letters in Python': 4,
#  u'Combining columns and removing NaNs Pandas': 2,
#  u'Drop all data in a pandas dataframe': 1,
#  u'How to assign default value while performing concat on DataFrames': 1,
#  u'Apply returning DataFrame when it should return a Series': 1,
#  u'Datetime header when reading in a file with pandas': 1,
#  u'How to query a PyTables frame_table saved via a Pandas Dataframe?': 1,
#  u'Get index of the minimum of multi-index Pandas DataFrame using level': 2,
#  u'Index numpy array with pd.Series of boolean': 2,
#  u'Running True/False statements on coordinates stored in two separate documents': 1,
#  u'Pandas date overlap': 0,
#  u'All rows within a given column must match, for all columns': 3,
#  u'Filter Pandas DataFrame depending on whether the filter value is specified': 1,
#  u'Converting Pandas dataframe to Spark Dataframe with unicode encoding error': 0,
#  u'Pandas: How to edit values in a column': 1,
#  u'what is &#39;SingleBlockManager&#39; in pandas?': 1,
#  u'Function to convert coordinates in pandas series and append as additional series': 3,
#  u'Convert Varied Text Fields of Duration to Seconds in Pandas': 2,
#  u'Add rows and columns to pandas dataframe based on a given list': 2,
#  u'pandas elementwise difference between two DatetimeIndex': 2,
#  u'Create a new variable to represent the last result in a time series with pandas': 1,
#  u'Create a DataFrame with DatetimeIndex with unique values by adding a timedelta': 1,
#  ...}

# %%
def tag_number_of_questions(data):
    
    tag_n_q = {}
    
    for i in range(len(data)):
        for j in data[i]['tags']:
            tag_n_q.setdefault(j,0)
            tag_n_q[j]+=1
            
    return tag_n_q

# %%
tag_num_of_questions = tag_number_of_questions(data_question_tag)

# %%
tag_num_of_questions['python']
# Out:
# 11174

# %%
def tag_number_of_answers(data):
    
    tag_n_a = {}
    
    for i in range(len(data)):
        for j in data[i]['tags']:
            tag_n_a.setdefault(j,0)
            tag_n_a[j]+=data[i]['answer_count']
            
    return tag_n_a

# %%
tag_num_of_answers = tag_number_of_answers(data_question_tag)

# %%
tag_num_of_answers['python']
# Out:
# 14754

# %% [markdown]
# # Analysis 5:
# ## Steps:
# 1. Find out the user whose questions have been downvoted the most.

# %%
def id_downvoted(data):
    id_down = {}
    for i in range(len(data)):
        if 'user_id' in data[i]['owner']: 
            id_down.setdefault(data[i]['owner']['user_id'],0)
            id_down[data[i]['owner']['user_id']]+=data[i]['score']
            
    sorted_down = sorted(id_down.items(), key=operator.itemgetter(1))
        
    return sorted_down

# %%
id_down_voted = id_downvoted(data_question_tag)

# %%
#User with ID 6612697 has got the most downvotes.

id_down_voted
# Out:
# [(6612697, -10),
#  (6894212, -8),
#  (5363621, -7),
#  (6375347, -7),
#  (6012341, -7),
#  (5876450, -7),
#  (6804939, -6),
#  (4774724, -6),
#  (6311384, -5),
#  (1871453, -5),
#  (7017871, -5),
#  (7051431, -5),
#  (6495030, -5),
#  (5505701, -4),
#  (5236124, -4),
#  (6440419, -4),
#  (5496911, -4),
#  (6146613, -4),
#  (6837454, -4),
#  (6186008, -4),
#  (5884532, -4),
#  (4098013, -3),
#  (2195729, -3),
#  (5857901, -3),
#  (6915557, -3),
#  (5870593, -3),
#  (3033977, -3),
#  (3491129, -3),
#  (6350613, -3),
#  (3655574, -3),
#  (5933064, -3),
#  (4157010, -3),
#  (6489064, -3),
#  (6835984, -3),
#  (3067748, -3),
#  (4110329, -3),
#  (3633380, -3),
#  (6852858, -3),
#  (5792480, -3),
#  (4608333, -3),
#  (5624176, -3),
#  (4289379, -3),
#  (5575597, -3),
#  (6526114, -3),
#  (2801236, -3),
#  (6715196, -3),
#  (4213875, -3),
#  (2013250, -3),
#  (5757515, -3),
#  (7019394, -3),
#  (6692030, -3),
#  (3969785, -3),
#  (5651960, -3),
#  (2424587, -3),
#  (1206923, -3),
#  (6930507, -2),
#  (4350205, -2),
#  (5519631, -2),
#  (6857038, -2),
#  (6324722, -2),
#  (6177375, -2),
#  (4801125, -2),
#  (5514696, -2),
#  (5710533, -2),
#  (5645803, -2),
#  (5760497, -2),
#  (6937437, -2),
#  (1298649, -2),
#  (2373748, -2),
#  (1648545, -2),
#  (6289064, -2),
#  (6531255, -2),
#  (4688190, -2),
#  (6744744, -2),
#  (3312344, -2),
#  (6605582, -2),
#  (6469439, -2),
#  (199556, -2),
#  (5048763, -2),
#  (2542738, -2),
#  (5868738, -2),
#  (5516494, -2),
#  (5213437, -2),
#  (6180139, -2),
#  (3763608, -2),
#  (6835979, -2),
#  (7024521, -2),
#  (6271136, -2),
#  (4501904, -2),
#  (6566438, -2),
#  (5256007, -2),
#  (4379529, -2),
#  (6600913, -2),
#  (6290272, -2),
#  (5961085, -2),
#  (1029706, -2),
#  (3604746, -2),
#  (4282224, -2),
#  (6019041, -2),
#  (5969922, -2),
#  (4203516, -2),
#  (2300116, -2),
#  (5892107, -2),
#  (5380433, -2),
#  (6543701, -2),
#  (4880751, -2),
#  (5290412, -2),
#  (197455, -2),
#  (4597167, -2),
#  (3120266, -2),
#  (5733516, -2),
#  (6446249, -2),
#  (6798534, -2),
#  (1637673, -2),
#  (6405535, -2),
#  (5930493, -2),
#  (6471219, -2),
#  (4266681, -2),
#  (5351440, -2),
#  (3285014, -1),
#  (2605182, -1),
#  (5947544, -1),
#  (5890240, -1),
#  (549094, -1),
#  (6026639, -1),
#  (3604836, -1),
#  (6545898, -1),
#  (4276733, -1),
#  (4871604, -1),
#  (3971910, -1),
#  (6521569, -1),
#  (2057086, -1),
#  (1336244, -1),
#  (2270136, -1),
#  (590335, -1),
#  (6620342, -1),
#  (6620395, -1),
#  (4941059, -1),
#  (6440269, -1),
#  (6115555, -1),
#  (4294015, -1),
#  (6702513, -1),
#  (3278309, -1),
#  (5686815, -1),
#  (779856, -1),
#  (5395845, -1),
#  (5203672, -1),
#  (6948610, -1),
#  (2672481, -1),
#  (2033588, -1),
#  (5269483, -1),
#  (6752430, -1),
#  (5097664, -1),
#  (7022803, -1),
#  (1452097, -1),
#  (6457622, -1),
#  (5368173, -1),
#  (3508627, -1),
#  (6649975, -1),
#  (6367782, -1),
#  (6154802, -1),
#  (6621793, -1),
#  (3828374, -1),
#  (5982950, -1),
#  (1854186, -1),
#  (4836149, -1),
#  (4983782, -1),
#  (1158313, -1),
#  (4780721, -1),
#  (6802433, -1),
#  (6056979, -1),
#  (6327367, -1),
#  (1387717, -1),
#  (4787431, -1),
#  (6595151, -1),
#  (6353215, -1),
#  (5516539, -1),
#  (6458707, -1),
#  (6614491, -1),
#  (5500391, -1),
#  (4673147, -1),
#  (5402286, -1),
#  (2821831, -1),
#  (4402942, -1),
#  (6409534, -1),
#  (6560280, -1),
#  (5738452, -1),
#  (6490995, -1),
#  (6345386, -1),
#  (6836322, -1),
#  (2207938, -1),
#  (1086155, -1),
#  (6918347, -1),
#  (6179024, -1),
#  (6648286, -1),
#  (6205926, -1),
#  (4370969, -1),
#  (1331978, -1),
#  (4952773, -1),
#  (4469565, -1),
#  (6083472, -1),
#  (6551706, -1),
#  (6140838, -1),
#  (5878758, -1),
#  (734189, -1),
#  (6403061, -1),
#  (5808464, -1),
#  (7066758, -1),
#  (6252746, -1),
#  (5002469, -1),
#  (4700250, -1),
#  (5199096, -1),
#  (6002053, -1),
#  (6079389, -1),
#  (112050, -1),
#  (5942861, -1),
#  (6624794, -1),
#  (4576889, -1),
#  (3855999, -1),
#  (4035775, -1),
#  (3937960, -1),
#  (5953266, -1),
#  (309010, -1),
#  (6936382, -1),
#  (3430238, -1),
#  (366640, -1),
#  (3635284, -1),
#  (6928513, -1),
#  (3848336, -1),
#  (3422389, -1),
#  (6699237, -1),
#  (5822696, -1),
#  (7002350, -1),
#  (6246100, -1),
#  (3553546, -1),
#  (5994855, -1),
#  (6240629, -1),
#  (5683778, -1),
#  (5741205, -1),
#  (7060136, -1),
#  (5745517, -1),
#  (4779818, -1),
#  (5058706, -1),
#  (6863702, -1),
#  (4954994, -1),
#  (2027333, -1),
#  (6585344, -1),
#  (5047467, -1),
#  (6937609, -1),
#  (3480068, -1),
#  (4373583, -1),
#  (6569059, -1),
#  (4660332, -1),
#  (5847130, -1),
#  (6566431, -1),
#  (6814867, -1),
#  (3293275, -1),
#  (5315799, -1),
#  (3153140, -1),
#  (5889919, -1),
#  (4801641, -1),
#  (6102294, -1),
#  (5889427, -1),
#  (6815270, -1),
#  (348081, -1),
#  (3841436, -1),
#  (6594488, -1),
#  (5971645, -1),
#  (2466763, -1),
#  (425727, -1),
#  (4783875, -1),
#  (6528805, -1),
#  (4218755, -1),
#  (5849272, -1),
#  (4464558, -1),
#  (5030131, -1),
#  (5906433, 0),
#  (5552408, 0),
#  (6692870, 0),
#  (6585004, 0),
#  (5488652, 0),
#  (4661264, 0),
#  (4005915, 0),
#  (945738, 0),
#  (2621477, 0),
#  (5537840, 0),
#  (3596337, 0),
#  (3842102, 0),
#  (6373432, 0),
#  (1998919, 0),
#  (1245262, 0),
#  (5232517, 0),
#  (6357081, 0),
#  (6185056, 0),
#  (2965601, 0),
#  (5988450, 0),
#  (6201445, 0),
#  (6840427, 0),
#  (5213098, 0),
#  (1253493, 0),
#  (6676599, 0),
#  (819330, 0),
#  (327702, 0),
#  (2728074, 0),
#  (1745038, 0),
#  (1946989, 0),
#  (6199534, 0),
#  (4317363, 0),
#  (7069877, 0),
#  (3178680, 0),
#  (2696565, 0),
#  (909515, 0),
#  (6136013, 0),
#  (5374161, 0),
#  (6488274, 0),
#  (6324437, 0),
#  (5812577, 0),
#  (6602969, 0),
#  (6275292, 0),
#  (2608081, 0),
#  (6382972, 0),
#  (5443623, 0),
#  (3144099, 0),
#  (4810108, 0),
#  (6176978, 0),
#  (1433643, 0),
#  (3318023, 0),
#  (3399944, 0),
#  (5390612, 0),
#  (3490069, 0),
#  (6537521, 0),
#  (5468983, 0),
#  (4383027, 0),
#  (2227093, 0),
#  (7020856, 0),
#  (3715124, 0),
#  (5963830, 0),
#  (6275400, 0),
#  (3547465, 0),
#  (5650055, 0),
#  (4358199, 0),
#  (3277133, 0),
#  (2023760, 0),
#  (1114453, 0),
#  (6651813, 0),
#  (794975, 0),
#  (6213179, 0),
#  (1462331, 0),
#  (5931373, 0),
#  (3719620, 0),
#  (3497084, 0),
#  (6558688, 0),
#  (464277, 0),
#  (6168960, 0),
#  (5093419, 0),
#  (1802629, 0),
#  (3342732, 0),
#  (5554585, 0),
#  (5940270, 0),
#  (5390753, 0),
#  (1851812, 0),
#  (3318185, 0),
#  (5274537, 0),
#  (2556340, 0),
#  (5718471, 0),
#  (1058210, 0),
#  (3080661, 0),
#  (6111705, 0),
#  (4096475, 0),
#  (3170788, 0),
#  (6930923, 0),
#  (3400176, 0),
#  (4539301, 0),
#  (2687490, 0),
#  (5874198, 0),
#  (6849055, 0),
#  (1345249, 0),
#  (3998252, 0),
#  (3932718, 0),
#  (6865456, 0),
#  (713266, 0),
#  (6513208, 0),
#  (6226500, 0),
#  (2677517, 0),
#  (5334456, 0),
#  (6395133, 0),
#  (2867798, 0),
#  (4253117, 0),
#  (1671793, 0),
#  (1330381, 0),
#  (4350583, 0),
#  (5718648, 0),
#  (2315711, 0),
#  (5194073, 0),
#  (7021184, 0),
#  (7029378, 0),
#  (5309063, 0),
#  (6587032, 0),
#  (6587033, 0),
#  (4539047, 0),
#  (5890731, 0),
#  (6447806, 0),
#  (4784245, 0),
#  (25282, 0),
#  (7017931, 0),
#  (4530884, 0),
#  (3229681, 0),
#  (1172169, 0),
#  (6144715, 0),
#  (189134, 0),
#  (2908879, 0),
#  (6603473, 0),
#  (6562520, 0),
#  (5847848, 0),
#  (5212969, 0),
#  (6161153, 0),
#  (6013700, 0),
#  (2458377, 0),
#  (4219671, 0),
#  (4088603, 0),
#  (6439876, 0),
#  (1196851, 0),
#  (5104436, 0),
#  (1303355, 0),
#  (6259527, 0),
#  (6693706, 0),
#  (475982, 0),
#  (2069858, 0),
#  (2385379, 0),
#  (1866679, 0),
#  (5038940, 0),
#  (2007910, 0),
#  (4186983, 0),
#  (5923698, 0),
#  (5882739, 0),
#  (5218452, 0),
#  (2909052, 0),
#  (1573761, 0),
#  (5960055, 0),
#  (1254285, 0),
#  (5949354, 0),
#  (6849439, 0),
#  (5702561, 0),
#  (4784285, 0),
#  (4478452, 0),
#  (5435554, 0),
#  (5817303, 0),
#  (4285400, 0),
#  (6415321, 0),
#  (3924957, 0),
#  (1426402, 0),
#  (6194150, 0),
#  (6923240, 0),
#  (4424682, 0),
#  (1418224, 0),
#  (5833718, 0),
#  (1344508, 0),
#  (5047302, 0),
#  (6685708, 0),
#  (6104077, 0),
#  (6510262, 0),
#  (1991697, 0),
#  (5622355, 0),
#  (328725, 0),
#  (6661151, 0),
#  (1254450, 0),
#  (5547062, 0),
#  (1066063, 0),
#  (5054655, 0),
#  (6411519, 0),
#  (4162717, 0),
#  (5424288, 0),
#  (5700531, 0),
#  (3302563, 0),
#  (5066951, 0),
#  (5473454, 0),
#  (5315468, 0),
#  (742827, 0),
#  (4534475, 0),
#  (5473482, 0),
#  (4891866, 0),
#  (6161633, 0),
#  (5833955, 0),
#  (2983144, 0),
#  (6341876, 0),
#  (5784822, 0),
#  (4457721, 0),
#  (5088513, 0),
#  (6399241, 0),
#  (6308055, 0),
#  (6079766, 0),
#  (3745050, 0),
#  (5895965, 0),
#  (1212562, 0),
#  (5555761, 0),
#  (5170483, 0),
#  (3948766, 0),
#  (5612856, 0),
#  (6866240, 0),
#  (4375876, 0),
#  (445327, 0),
#  (4948088, 0),
#  (1122534, 0),
#  (5784934, 0),
#  (1018770, 0),
#  (4941166, 0),
#  (4744765, 0),
#  (6727028, 0),
#  (6209004, 0),
#  (5057431, 0),
#  (6311689, 0),
#  (5378103, 0),
#  (5711256, 0),
#  (6200218, 0),
#  (6309278, 0),
#  (779681, 0),
#  (5793186, 0),
#  (5619511, 0),
#  (5894385, 0),
#  (6596015, 0),
#  (5918963, 0),
#  (5301692, 0),
#  (5368737, 0),
#  (2401736, 0),
#  (6327202, 0),
#  (3040845, 0),
#  (3720656, 0),
#  (2942419, 0),
#  (4774835, 0),
#  (6809062, 0),
#  (6063593, 0),
#  (6171482, 0),
#  (4679153, 0),
#  (4793864, 0),
#  (6170154, 0),
#  (5383727, 0),
#  (4515376, 0),
#  (1762870, 0),
#  (3294779, 0),
#  (4874506, 0),
#  (2866103, 0),
#  (633182, 0),
#  (1361495, 0),
#  (525913, 0),
#  (1817530, 0),
#  (3442271, 0),
#  (3006737, 0),
#  (3933805, 0),
#  (2713198, 0),
#  (7071359, 0),
#  (1164938, 0),
#  (4949664, 0),
#  (5433002, 0),
#  (6063789, 0),
#  (5932720, 0),
#  (2901683, 0),
#  (6101962, 0),
#  (517835, 0),
#  (1132378, 0),
#  (4261588, 0),
#  (3393746, 0),
#  (2962477, 0),
#  (6096625, 0),
#  (4464145, 0),
#  (5438421, 0),
#  (4818693, 0),
#  (6891272, 0),
#  (3736362, 0),
#  (4073229, 0),
#  (2377489, 0),
#  (6078658, 0),
#  (165658, 0),
#  (3671840, 0),
#  (5785385, 0),
#  (6866735, 0),
#  (5872607, 0),
#  (6252349, 0),
#  (6670143, 0),
#  (673600, 0),
#  (2385736, 0),
#  (5210424, 0),
#  (5801816, 0),
#  (6694750, 0),
#  (2287458, 0),
#  (6301542, 0),
#  (4072706, 0),
#  (5769068, 0),
#  (3146064, 0),
#  (2770803, 0),
#  (4687733, 0),
#  (5785465, 0),
#  (5539711, 0),
#  (1902489, 0),
#  (280476, 0),
#  (5842864, 0),
#  (4612424, 0),
#  (3393463, 0),
#  (3939696, 0),
#  (5760960, 0),
#  (985030, 0),
#  (4376519, 0),
#  (7030731, 0),
#  (6236113, 0),
#  (6416338, 0),
#  (6301651, 0),
#  (5310427, 0),
#  (6604780, 0),
#  (5894625, 0),
#  (1918965, 0),
#  (6227959, 0),
#  (5842939, 0),
#  (3909638, 0),
#  (6555655, 0),
#  (6866960, 0),
#  (1755155, 0),
#  (5054616, 0),
#  (5957663, 0),
#  (4032552, 0),
#  (6457390, 0),
#  (3106889, 0),
#  (3743275, 0),
#  (6039633, 0),
#  (6228056, 0),
#  (3153975, 0),
#  (5056613, 0),
#  (5425617, 0),
#  (6498416, 0),
#  (3197044, 0),
#  (4570132, 0),
#  (460928, 0),
#  (5286020, 0),
#  (6039700, 0),
#  (363546, 0),
#  (2951327, 0),
#  (5854307, 0),
#  (4221094, 0),
#  (1779888, 0),
#  (5056689, 0),
#  (5769402, 0),
#  (6678715, 0),
#  (714443, 0),
#  (2628641, 0),
#  (5589194, 0),
#  (2433617, 0),
#  (6026959, 0),
#  (2551683, 0),
#  (6039787, 0),
#  (4802797, 0),
#  (6243321, 0),
#  (6341997, 0),
#  (2246905, 0),
#  (6875401, 0),
#  (6801683, 0),
#  (5079813, 0),
#  (1419544, 0),
#  (5173575, 0),
#  (5456001, 0),
#  (2307804, 0),
#  (6099336, 0),
#  (534238, 0),
#  (3288346, 0),
#  (3262787, 0),
#  (4671812, 0),
#  (2369865, 0),
#  (5626764, 0),
#  (6580566, 0),
#  (1345888, 0),
#  (1589038, 0),
#  (2468196, 0),
#  (2804070, 0),
#  (2869616, 0),
#  (6048114, 0),
#  (6318479, 0),
#  (2959762, 0),
#  (2406128, 0),
#  (6269347, 0),
#  (3800761, 0),
#  (6916524, 0),
#  (6203822, 0),
#  (4049331, 0),
#  (3434933, 0),
#  (5786891, 0),
#  (1366996, 0),
#  (5881274, 0),
#  (4123073, 0),
#  (5212614, 0),
#  (5737523, 0),
#  (5335501, 0),
#  (5728718, 0),
#  (1829329, 0),
#  (2386385, 0),
#  (6908374, 0),
#  (6519586, 0),
#  (5851615, 0),
#  (5094480, 0),
#  (1047569, 0),
#  (5130728, 0),
#  (5376493, 0),
#  (6433263, 0),
#  (4213235, 0),
#  (1624577, 0),
#  (3983879, 0),
#  (4179714, 0),
#  (1329688, 0),
#  (5024858, 0),
#  (1739297, 0),
#  (6154787, 0),
#  (1813039, 0),
#  (5932561, 0),
#  (3394108, 0),
#  (4929813, 0),
#  (5112246, 0),
#  (6049040, 0),
#  (2312788, 0),
#  (6621781, 0),
#  (4901462, 0),
#  (5608226, 0),
#  (1501805, 0),
#  (6006547, 0),
#  (428664, 0),
#  (2476665, 0),
#  (1591930, 0),
#  (1804926, 0),
#  (5844182, 0),
#  (6670985, 0),
#  (1026699, 0),
#  (6039222, 0),
#  (7023257, 0),
#  (3115675, 0),
#  (6089373, 0),
#  (2812590, 0),
#  (3492527, 0),
#  (5853731, 0),
#  (6663283, 0),
#  (1941253, 0),
#  (7072445, 0),
#  (5950143, 0),
#  (6063825, 0),
#  (5530061, 0),
#  (4713173, 0),
#  (3508956, 0),
#  (3861804, 0),
#  (5999331, 0),
#  (2394868, 0),
#  (6468053, 0),
#  (5096163, 0),
#  (6261509, 0),
#  (1911563, 0),
#  (3705620, 0),
#  (6949666, 0),
#  (2403107, 0),
#  (6179622, 0),
#  (3877674, 0),
#  (6172938, 0),
#  (2411320, 0),
#  (1428281, 0),
#  (815443, 0),
#  (5663568, 0),
#  (1493850, 0),
#  (4962106, 0),
#  (6785906, 0),
#  (2648947, 0),
#  (4092108, 0),
#  (1149813, 0),
#  (1672800, 0),
#  (3135460, 0),
#  (5147526, 0),
#  (5916082, 0),
#  (3697550, 0),
#  (6506308, 0),
#  (4457601, 0),
#  (519074, 0),
#  (5942187, 0),
#  (5950390, 0),
#  (6001140, 0),
#  (5712829, 0),
#  (5896011, 0),
#  (2858145, 0),
#  (4213706, 0),
#  (2378710, 0),
#  (6345773, 0),
#  (6589409, 0),
#  (4836327, 0),
#  (2296815, 0),
#  (6917105, 0),
#  (5270515, 0),
#  (5675169, 0),
#  (6252372, 0),
#  (4475902, 0),
#  (5696518, 0),
#  (6206471, 0),
#  (2631513, 0),
#  (1992234, 0),
#  (6186845, 0),
#  (3132595, 0),
#  (461887, 0),
#  (5884994, 0),
#  (6152715, 0),
#  (5431734, 0),
#  (4697173, 0),
#  (6401211, 0),
#  (3024742, 0),
#  (5893232, 0),
#  (3582887, 0),
#  (6625047, 0),
#  (5730994, 0),
#  (6630522, 0),
#  (1584253, 0),
#  (6520001, 0),
#  (1887370, 0),
#  (2080411, 0),
#  (5983405, 0),
#  (6171823, 0),
#  (6581425, 0),
#  (2198720, 0),
#  (1494214, 0),
#  (6843601, 0),
#  (4709363, 0),
#  (5893331, 0),
#  (6232789, 0),
#  (6900963, 0),
#  (6022565, 0),
#  (2828157, 0),
#  (216275, 0),
#  (6546978, 0),
#  (1903880, 0),
#  (6171250, 0),
#  (3427605, 0),
#  (2952470, 0),
#  (6158213, 0),
#  (3801648, 0),
#  (3208484, 0),
#  (7023930, 0),
#  (6279734, 0),
#  (1211620, 0),
#  (4338331, 0),
#  (6122727, 0),
#  (1743419, 0),
#  (1486190, 0),
#  (2870440, 0),
#  (4001154, 0),
#  (1297798, 0),
#  (5336458, 0),
#  (5107084, 0),
#  (3321229, 0),
#  (3853711, 0),
#  (6100888, 0),
#  (5999890, 0),
#  (6604697, 0),
#  (6917544, 0),
#  (5097372, 0),
#  (970155, 0),
#  (6457697, 0),
#  (3820991, 0),
#  (403360, 0),
#  (4804043, 0),
#  (6172112, 0),
#  (3821012, 0),
#  (893518, 0),
#  (6196696, 0),
#  (60893, 0),
#  (6229482, 0),
#  (6070759, 0),
#  (6696432, 0),
#  (4574710, 0),
#  (3059201, 0),
#  (3921356, 0),
#  (5729796, 0),
#  (4804108, 0),
#  (6671889, 0),
#  (5484958, 0),
#  (3419686, 0),
#  (3165737, 0),
#  (1006855, 0),
#  (5828392, 0),
#  (5224179, 0),
#  (4607549, 0),
#  (2992055, 0),
#  (5393996, 0),
#  (6139149, 0),
#  (2824120, 0),
#  (4705876, 0),
#  (5405967, 0),
#  (3550480, 0),
#  (2035298, 0),
#  (691816, 0),
#  (539923, 0),
#  (6950525, 0),
#  (1707654, 0),
#  (4157068, 0),
#  (2212461, 0),
#  (6688405, 0),
#  (6491801, 0),
#  (3796635, 0),
#  (601770, 0),
#  (306869, 0),
#  (6385338, 0),
#  (6459078, 0),
#  (3624650, 0),
#  (6696657, 0),
#  (5975765, 0),
#  (6000343, 0),
#  (5500634, 0),
#  (4959970, 0),
#  (741099, 0),
#  (4819376, 0),
#  (6193791, 0),
#  (6713085, 0),
#  (2005352, 0),
#  (2141956, 0),
#  (5713671, 0),
#  (6442767, 0),
#  (4747049, 0),
#  (6500141, 0),
#  (6057786, 0),
#  (4648617, 0),
#  (2658138, 0),
#  (5440143, 0),
#  (1159005, 0),
#  (1257318, 0),
#  (6672237, 0),
#  (6590324, 0),
#  (4861822, 0),
#  (6655874, 0),
#  (2690949, 0),
#  (2301249, 0),
#  (6868875, 0),
#  (5872396, 0),
#  (2592657, 0),
#  (5189524, 0),
#  (356875, 0),
#  (6004076, 0),
#  (944779, 0),
#  (5984172, 0),
#  (6557618, 0),
#  (4992953, 0),
#  (4403872, 0),
#  (3531228, 0),
#  (1684129, 0),
#  (2305993, 0),
#  (6590412, 0),
#  (3796947, 0),
#  (3313622, 0),
#  (4091874, 0),
#  (5793508, 0),
#  (5924426, 0),
#  (6680564, 0),
#  (5992438, 0),
#  (6336503, 0),
#  (6516735, 0),
#  (5631318, 0),
#  (2690051, 0),
#  (6204575, 0),
#  (6221839, 0),
#  (1773592, 0),
#  (6410929, 0),
#  (6869037, 0),
#  (5886005, 0),
#  (3756090, 0),
#  (4919355, 0),
#  (5886019, 0),
#  (307283, 0),
#  (5312606, 0),
#  (1325863, 0),
#  (4157564, 0),
#  (5935229, 0),
#  (4264062, 0),
#  (6631551, 0),
#  (2762775, 0),
#  (3421652, 0),
#  (5132432, 0),
#  (266387, 0),
#  (4100253, 0),
#  (5004656, 0),
#  (6328486, 0),
#  (6697127, 0),
#  (1667241, 0),
#  (3772587, 0),
#  (6623945, 0),
#  (6639802, 0),
#  (5231306, 0),
#  (5238982, 0),
#  (3510483, 0),
#  (5705943, 0),
#  (5654564, 0),
#  (807631, 0),
#  (6000860, 0),
#  (4141279, 0),
#  (6476002, 0),
#  (4387537, 0),
#  (3228798, 0),
#  (748925, 0),
#  (6876542, 0),
#  (4714742, 0),
#  (6356523, 0),
#  (479490, 0),
#  (2563755, 0),
#  (5201562, 0),
#  (1446154, 0),
#  (4255107, 0),
#  ...]
